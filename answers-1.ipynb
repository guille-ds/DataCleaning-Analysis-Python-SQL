# %% [markdown]
# # Data Engineer @ Embat - Hiring Test

# %% [markdown]
# This notebook has several tasks to test the abilities of Data Engineer candidates @ Embat. Main topic is data analytics with Pyhton and SQL. We don't expect you to know how to solve all these tasks from memory, so we appreciate that you also note down all you had to google, so we get an idea of your thinking process. Also, its okay if you don't complete some tasks, but please note down your blockers.

# %% [markdown]
# ## Part I - Data analytics with Python

# %% [markdown]
# (I.1) Load the sales.csv file into a pandas dataframe and answer the following questions:
# * How many rows and colums do we have? How does our dataframe look like?
# * How many unique values do we have in each column?
# * Statistical values (min, max, avg, deviaton and percentiles) for the amount and the price of the coffee sold.
# * Feel free to add any other information / metrics you may find interesting.

# %%
import pandas as pd
import numpy as np

# Load the sales.csv file into pandas dataframe
df = pd.read_csv("./sales.csv", parse_dates=["timestamp"])

# How many rows and columns?
print(f'{df.shape[0]} rows and {df.shape[1]} columns in the DataFrame')
df
# Out:
# 1000 rows and 9 columns in the DataFrame
#           name   surname          address  postal_code                 city  \
# 0         Cleo  Melendez  Calle U, nº 377        44175               Orrios
# 1        Ryder      Mack  Calle A, nº 320        37127               Espeja
# 2        Yasir    Glover   Calle T, nº 31        10192           Torremocha
# 3        Eagan    Suarez  Calle L, nº 164        50286  Villalba de Perejil
# 4     Kimberly    Farmer  Calle K, nº 229        48079            Errigoiti
# ..         ...       ...              ...          ...                  ...
# 995  Demetrius    Adkins  Calle T, nº 350        46081               Canals
# 996    Stephen    Barlow  Calle Q, nº 259         6042               Cheles
# 997      Willa   Mueller  Calle G, nº 244        14018           Carpio, El
# 998    Wyoming    Campos  Calle G, nº 114        22162              Novales
# 999     Athena   Michael   Calle E, nº 35        48026                 Dima
#
#                timestamp coffee_type amount_kg price_kg
# 0     5/10/2022 20:23:47           8     1,250     24,8
# 1    31/01/2022 16:52:33           1     0,500     34,8
# 2    31/10/2022 15:16:48           2     0,250     20,4
# 3     11/02/2022 3:16:39           1     1,000     31,4
# 4    22/02/2022 12:09:00           1     0,750     24,2
# ..                   ...         ...       ...      ...
# 995  24/10/2022 18:26:59           6     5,000     27,9
# 996   15/03/2022 4:30:30           5     3,000     32,8
# 997   22/04/2022 0:52:59           5     1,250     15,3
# 998  27/12/2022 15:39:02           5     3,000       31
# 999  10/02/2022 16:07:34           8     1,500       34
#
# [1000 rows x 9 columns]

# %%
# Taking a look to 'coffee_type' column. Not so clean
df['coffee_type'].unique()
# Out:
# array(['8', '1', '2', '3', '7', '4', '6', '5', nan, 'siete', 'seis'],
#       dtype=object)

# %%
# Delete 3 rows with NaN values in 'coffee_type' column:
df.dropna(subset='coffee_type', inplace=True)

# And replacing some values:
df['coffee_type'] = df['coffee_type'].replace({'siete': '7', 'seis': '6'}).astype(int)

# %%
# checking again: 
df['coffee_type'].value_counts(dropna = False)
# Out:
# 3    148
# 8    136
# 2    123
# 7    122
# 5    120
# 1    119
# 6    118
# 4    111
# Name: coffee_type, dtype: int64

# %%
# How many unique values do we have in each column?
print ("UNIQUE VALUES")
print(df.nunique(dropna=False))
# Out:
# UNIQUE VALUES
# name           666
# surname        633
# address        957
# postal_code    995
# city           997
# timestamp      997
# coffee_type      8
# amount_kg       12
# price_kg       201
# dtype: int64

# %%
# Statistical values 
df[['amount_kg','price_kg']].describe()

# Percentiles are not calculated so it means that not all datapoints are numeric. In fact they are object data (strings and/or NaN).
# Out:
#        amount_kg price_kg
# count        997      994
# unique        12      200
# top        1,250     24,8
# freq         122       10

# %%
# Taking a look to 'amount_kg' and 'price_kg' we can see 3 NaN in 'price_kg'
df[['amount_kg','price_kg']].isna().sum()
# Out:
# amount_kg    0
# price_kg     3
# dtype: int64

# %%
df.dropna(subset='price_kg', inplace=True)
df[['amount_kg','price_kg']].isna().sum()
# Out:
# amount_kg    0
# price_kg     0
# dtype: int64

# %%
# With both columns clean, we can change str to float in order to be able to calculate percentiles:
not_int_columns = ['amount_kg','price_kg']
for e in not_int_columns:
    df[e] = df[e].str.replace(",",".").astype(float)

# %%
df.amount_kg.describe()

# Strange max (5000.000) in the amount_kg. We may have some outliers.
# Out:
# count     994.000000
# mean        9.870976
# std       172.092504
# min         0.250000
# 25%         0.750000
# 50%         1.250000
# 75%         3.000000
# max      5000.000000
# Name: amount_kg, dtype: float64

# %%
df.amount_kg.sort_values(ascending=False)
# Out:
# 570    5000.00
# 581    1500.00
# 580    1500.00
# 870       5.00
# 96        5.00
#         ...
# 632       0.25
# 82        0.25
# 301       0.25
# 569       0.25
# 420       0.25
# Name: amount_kg, Length: 994, dtype: float64

# %% [markdown]
# Three outliers detected in "amount_kg" column. We can fix it replacing values

# %%
df.loc[570,"amount_kg"] = 5.0
df.loc[581,"amount_kg"] = 1.5
df.loc[580,"amount_kg"] = 1.5

# %%
# Now we can check that the outliers are gone. Fixed.
df.amount_kg.sort_values(ascending=False)
# Out:
# 805    5.00
# 620    5.00
# 848    5.00
# 853    5.00
# 657    5.00
#        ...
# 632    0.25
# 82     0.25
# 301    0.25
# 569    0.25
# 420    0.25
# Name: amount_kg, Length: 994, dtype: float64

# %%
# So now we can have proper statistical values
df[['amount_kg','price_kg']].describe()
# Out:
#         amount_kg    price_kg
# count  994.000000  994.000000
# mean     1.830734   25.267907
# std      1.443318    5.727261
# min      0.250000   15.000000
# 25%      0.750000   20.400000
# 50%      1.250000   25.400000
# 75%      3.000000   30.300000
# max      5.000000   35.000000

# %%
# Also we can check which column has NaN
count_nan_in_df = df.isna().sum()
print(count_nan_in_df)
# Out:
# name           0
# surname        0
# address        0
# postal_code    0
# city           0
# timestamp      0
# coffee_type    0
# amount_kg      0
# price_kg       0
# dtype: int64

# %%
# Checking which rows has no numeric datapoints (NaN)
df_nans = df[['coffee_type','amount_kg','price_kg']]
count_nan_in_df = df_nans.isna().sum()
count_nan_in_df
# Out:
# coffee_type    0
# amount_kg      0
# price_kg       0
# dtype: int64

# %%
# Checking each column type:
df.info()

# We should check 'timestamp' dtype in order to use the column as 'datetime'
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 994 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         994 non-null    object
#  1   surname      994 non-null    object
#  2   address      994 non-null    object
#  3   postal_code  994 non-null    int64
#  4   city         994 non-null    object
#  5   timestamp    994 non-null    object
#  6   coffee_type  994 non-null    int64
#  7   amount_kg    994 non-null    float64
#  8   price_kg     994 non-null    float64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 109.9+ KB

# %% [markdown]
# ### Checking and setting 'timestamp' column to datetime:

# %%
# Assign 'timestamp' to a variable so I can work with it independently
dates = df['timestamp']

# %%
# Trying to convert 'timestamp' column to datetime, I can raise some errors.
# Switching to 'coerce' I avoid the errors, convert them into NaT so I can later locate them in df
df2 = pd.to_datetime(dates, errors = 'coerce')

# %%
# Searching NaN in 'timestamp'
df2.isna().value_counts()

# 5 NaN found
# Out:
# False    989
# True       5
# Name: timestamp, dtype: int64

# %%
# Indexes which rows has NaN:
nan_index = df2[df2.isna()].index
df['timestamp'].loc[nan_index]

# Looking at the df data, we can see some wrong year values (year 3022) raising "OutOfBoundsDatetime".
# Out:
# 297    9/08/3022 22:47:07
# 461    10/08/3022 3:21:10
# 483    9/08/3022 22:00:10
# 626     9/08/3022 4:58:42
# 855     9/08/3022 0:41:09
# Name: timestamp, dtype: object

# %%
# In case we want to fix that datapoints we could replace the wrong year doing it in advance as shown below:
for e in nan_index:
    valid_date = df['timestamp'][e].replace("3022","2022")
    df.loc[e,'timestamp'] = valid_date

# %%
# With all 'timestamp' datapoints in range, now we can convert the column to_datetime with no errors:
df['timestamp'] = pd.to_datetime(df['timestamp'], errors = 'raise')

# %% [markdown]
# (I.2) Now please load the types.csv and get the following data. Please show the country and coffee variety in the results, not just the type numbers:
# * The total amount of Arabica coffee from Uganda sold in January 2022
# * The average price of Arabica coffee from Brasil in Q1 2022.
# * Same for Q2, Q3 and Q4 respectively.
# * The total sales amount per source country.
# * The total sales amount per shipping address province.
# * In which province did we sell the higher cost orders on average?

# %%
# in order to merge the 2 dataframes, I should rename the shared column 'type'
df.columns = df.columns.str.replace('coffee_type', 'type')

# %%
# Load the types.csv file into pandas dataframe
df_types = pd.read_csv("./types.csv")
df_types
# Out:
#    type    country  variety                                        description
# 0     1      Kenia  Arabica  EXCEPTIONALLY DARK AND CREAMY COFFEE. INTENSIT...
# 1     2     Brasil  Arabica     POWERFUL AND CONTRASTING COFFEE. INTENSITY  10
# 2     3     Uganda  Arabica  HARMONIOUSLY BALANCED AND THICK BODY COFFEE. I...
# 3     4   Colombia  Arabica           POTENT AND ROASTED COFFEE. INTENSITY  10
# 4     5   Colombia  Robusta      FRUITY WITH FINE ACIDITY COFFEE. INTENSITY  5
# 5     6    Vietnam  Robusta             SWEET COFFEE AND CEREALS. INTENSITY  4
# 6     7     Brasil  Robusta         COFFEE WITH ROBUSTA MONSOON. INTENSITY  11
# 7     8  Indonesia  Robusta                    WET-HULLED COFFEE. INTENSITY  8

# %%
left = df
right = df_types
result = pd.merge(left, right, on='type')
result
# Out:
#         name    surname          address  postal_code                city  \
# 0       Cleo   Melendez  Calle U, nº 377        44175              Orrios
# 1      Haley      Rivas  Calle K, nº 369        19095  Condemios de Abajo
# 2     Andrew    Whitley  Calle M, nº 196        47073    Herrín de Campos
# 3     Galvin    Houston  Calle G, nº 355        19166   Málaga del Fresno
# 4         Hu      Brock  Calle T, nº 300        39058             Rasines
# ..       ...        ...              ...          ...                 ...
# 989     Rana  Underwood  Calle B, nº 154         4085            Somontín
# 990   Baxter     Parker   Calle T, nº 32         8219     Vilassar de Mar
# 991  Stephen     Barlow  Calle Q, nº 259         6042              Cheles
# 992    Willa    Mueller  Calle G, nº 244        14018          Carpio, El
# 993  Wyoming     Campos  Calle G, nº 114        22162             Novales
#
#               timestamp  type  amount_kg  price_kg    country  variety  \
# 0   2022-05-10 20:23:47     8       1.25      24.8  Indonesia  Robusta
# 1   2022-02-25 12:22:12     8       0.75      29.2  Indonesia  Robusta
# 2   2022-10-16 04:38:07     8       0.75      25.7  Indonesia  Robusta
# 3   2022-08-31 17:58:53     8       5.00      20.3  Indonesia  Robusta
# 4   2022-05-16 07:25:14     8       3.00      27.6  Indonesia  Robusta
# ..                  ...   ...        ...       ...        ...      ...
# 989 2022-02-08 04:39:34     5       2.00      24.5   Colombia  Robusta
# 990 2022-10-18 19:25:27     5       0.50      26.0   Colombia  Robusta
# 991 2022-03-15 04:30:30     5       3.00      32.8   Colombia  Robusta
# 992 2022-04-22 00:52:59     5       1.25      15.3   Colombia  Robusta
# 993 2022-12-27 15:39:02     5       3.00      31.0   Colombia  Robusta
#
#                                        description
# 0                  WET-HULLED COFFEE. INTENSITY  8
# 1                  WET-HULLED COFFEE. INTENSITY  8
# 2                  WET-HULLED COFFEE. INTENSITY  8
# 3                  WET-HULLED COFFEE. INTENSITY  8
# 4                  WET-HULLED COFFEE. INTENSITY  8
# ..                                             ...
# 989  FRUITY WITH FINE ACIDITY COFFEE. INTENSITY  5
# 990  FRUITY WITH FINE ACIDITY COFFEE. INTENSITY  5
# 991  FRUITY WITH FINE ACIDITY COFFEE. INTENSITY  5
# 992  FRUITY WITH FINE ACIDITY COFFEE. INTENSITY  5
# 993  FRUITY WITH FINE ACIDITY COFFEE. INTENSITY  5
#
# [994 rows x 12 columns]

# %%
# The total amount of Arabica coffee from Uganda sold in January 2022:

answer_1 = result[(result['country']=='Uganda') & (result['variety']=='Arabica') & (result['timestamp'].dt.month==1)]
col = ['timestamp','type', 'variety', 'country', 'amount_kg']
out = result[col].groupby(by = ['country', 'type', 'variety', answer_1['timestamp'].dt.month]).agg({'amount_kg':'sum'})
out
# Out:
#                                 amount_kg
# country type variety timestamp
# Uganda  3    Arabica 1.0            16.25

# %%
# The average price of Arabica coffee from Brasil in Q1-Q2-Q3-Q4 2022:

def quarter(quarter):
    answer_2 = result[(result['country']=='Brasil') & (result['timestamp'].dt.quarter==e) & (result['variety']=='Arabica')]
    col = ['timestamp','type', 'variety', 'country', 'price_kg']
    out = result[col].groupby(by = ['country', 'type', 'variety', answer_2['timestamp'].dt.quarter]).agg({'price_kg':'mean'})
    return(display(out))

for e in range(1,5):
    print(f'Average price Quarter {e}')
    quarter(e)
# Out:
# Average price Quarter 1
#                                  price_kg
# country type variety timestamp
# Brasil  2    Arabica 1.0        26.268966
# Average price Quarter 2
#                                  price_kg
# country type variety timestamp
# Brasil  2    Arabica 2.0        26.769231
# Average price Quarter 3
#                                  price_kg
# country type variety timestamp
# Brasil  2    Arabica 3.0        23.830769
# Average price Quarter 4
#                                  price_kg
# country type variety timestamp
# Brasil  2    Arabica 4.0        24.365517

# %%
# The total sales amount per source country:

# Let's create a new column called 'sales_amount':
result['sales_amount'] = result['amount_kg'] * result['price_kg']

# %%
col = ['country', 'variety', 'type', 'sales_amount']
out = result[col].groupby(by = ['country', 'variety', 'type']).agg({'sales_amount':'sum'})
out
# Out:
#                         sales_amount
# country   variety type
# Brasil    Arabica 2         5692.875
#           Robusta 7         4770.975
# Colombia  Arabica 4         5528.950
#           Robusta 5         6039.550
# Indonesia Robusta 8         6352.675
# Kenia     Arabica 1         4805.200
# Uganda    Arabica 3         7440.325
# Vietnam   Robusta 6         5482.475

# %% [markdown]
# ### Provinces:
# How to create a new column with province names:
# - A dictionary {k:v} k=postal_code, v=provincia
# - A function formating postal codes (5 digits, filling zeros)
# - A function assigns province names according to the postal codes in the dict.

# %%
# I create a dict with postal codes and provinces out of a postal_codes.csv
import csv
codes_dict = {}
with open('postal_codes.csv', newline='') as pcodes_cfile:
    reader = csv.DictReader(pcodes_cfile)
    for row in reader:
        codes_dict[row['codigo']] = row['provincia'][1:]
print (codes_dict)
# Out:
# {'02': 'Albacete', '03': 'Alicante', '04': 'Almería', '01': 'Álava', '33': 'Asturias', '05': 'Ávila', '06': 'Badajoz', '07': 'Baleares', '08': 'Barcelona', '48': 'Bizkaia', '09': 'Burgos', '10': 'Cáceres', '11': 'Cádiz', '39': 'Cantabria', '12': 'Castellón', '13': 'Ciudad Real', '14': 'Córdoba', '15': 'Coruña', '16': 'Cuenca', '20': 'Gipuzkoa', '17': 'Girona', '18': 'Granada', '19': 'Guadalajara', '21': 'Huelva', '22': 'Huesca', '23': 'Jaén', '24': 'León', '25': 'Lleida', '27': 'Lugo', '28': 'Madrid', '29': 'Málaga', '30': 'Murcia', '31': 'Navarra', '32': 'Ourense', '34': 'Palencia', '35': 'Las Palmas', '36': 'Pontevedra', '26': 'La Rioja', '37': 'Salamanca', '38': 'Santa Cruz de Tenerife', '40': 'Segovia', '41': 'Sevilla', '42': 'Soria', '43': 'Tarragona', '44': 'Teruel', '45': 'Toledo', '46': 'Valencia', '47': 'Valladolid', '49': 'Zamora', '50': 'Zaragoza', '51': 'Ceuta', '52': 'Melilla'}

# %%
# Change 'postal_code' format to str:
result['postal_code'] = result['postal_code'].astype(str)

# %%
# Fill postal_code string with zeros till 5 digits
def codes_zeros (e):
    if len(str(e))>5:
        e = "0"
    e = str(e).zfill(5)
    return(e)

# Return provinces from codes_dict based on postal codes:
def province (e):
    return codes_dict.get(e[:2], "Not_Found" )

# %%
# Modify 'postal_code' 
result['postal_code'] = result['postal_code'].apply(codes_zeros)

# Create a new column 'province' in the 'result' dataframe
result['province'] = result['postal_code'].apply(province)

# %%
# The total sales amount per shipping address province.

# We need to create a new column for that and infer the province from the postal code
col = ['province', 'variety', 'type', 'sales_amount']
out = result[col].groupby(by = ['province']).agg({'sales_amount':'sum'}).sort_values(by="sales_amount",ascending=False)
#out.sales_amount.sort_values(ascending=False)
out.head()
# Out:
#            sales_amount
# province
# Burgos         2117.850
# Barcelona      2087.700
# Cuenca         1841.750
# Lleida         1731.600
# Zamora         1705.125

# %%
# Some postal_codes were not introduced properly in the df
result[(result == 'Not_Found').any(axis=1)]
# Out:
#            name surname          address postal_code         city  \
# 268  Chancellor  Burris    Calle O, nº 8       00000  Colmenarejo
# 319      Olivia   David  Calle J, nº 205       00000   Medinaceli
# 551        Reed   Meyer   Calle T, nº 10       00000       Terrer
# 689     Griffin   Wiley  Calle C, nº 193       00000        Beade
# 859     Shelley   Sykes  Calle K, nº 231       99999         Loiu
# 973       Bruce   Kirby  Calle N, nº 147       99999      Bimenes
#
#               timestamp  type  amount_kg  price_kg   country  variety  \
# 268 2022-05-28 21:56:52     2       0.25      25.0    Brasil  Arabica
# 319 2022-07-22 04:19:58     2       2.00      22.8    Brasil  Arabica
# 551 2022-05-23 21:02:37     7       0.75      28.5    Brasil  Robusta
# 689 2022-08-16 18:22:57     4       2.00      34.8  Colombia  Arabica
# 859 2022-11-04 15:54:30     6       5.00      33.8   Vietnam  Robusta
# 973 2022-01-20 15:57:57     5       0.50      18.1  Colombia  Robusta
#
#                                         description  sales_amount   province
# 268  POWERFUL AND CONTRASTING COFFEE. INTENSITY  10         6.250  Not_Found
# 319  POWERFUL AND CONTRASTING COFFEE. INTENSITY  10        45.600  Not_Found
# 551      COFFEE WITH ROBUSTA MONSOON. INTENSITY  11        21.375  Not_Found
# 689        POTENT AND ROASTED COFFEE. INTENSITY  10        69.600  Not_Found
# 859          SWEET COFFEE AND CEREALS. INTENSITY  4       169.000  Not_Found
# 973   FRUITY WITH FINE ACIDITY COFFEE. INTENSITY  5         9.050  Not_Found

# %%
# In which province did we sell the higher cost orders on average?
col = ['province', 'variety', 'type', 'sales_amount']
out = result[col].groupby(by = ['province']).agg({'sales_amount':'mean'})
out.sort_values(['sales_amount'], ascending = False).head()
# Out:
#                         sales_amount
# province
# Santa Cruz de Tenerife     65.400000
# Huelva                     63.937500
# Cuenca                     63.508621
# Alicante                   62.295000
# Lleida                     61.842857

# %% [markdown]
# (I.3) Using the dictionary below -where the keys are the types and the values the commercial names-, please add a new column to the types dataframe showing this commercial name.

# %%
coffee = {'1': 'Kenia (A)',
          '2': 'Brasil (A)',
          '3': 'Uganda (A)',
          '4': 'Colombia (A)',
          '5': 'Colombia (R)',
          '6': 'Vietnam (R)',
          '7': 'Brasil (R)',
          '8': 'Indonesia (R)'}

# %%
# As dictionary keys are "str" but df['type'] are "int", so I modify the dict changing the keys type to int:
coffee = {int(k):v for k,v in coffee.items()}

# Insert blocks here to complete the task.
df_types['commercial_name'] = df_types['type'].map(coffee)
df_types
# Out:
#    type    country  variety  \
# 0     1      Kenia  Arabica
# 1     2     Brasil  Arabica
# 2     3     Uganda  Arabica
# 3     4   Colombia  Arabica
# 4     5   Colombia  Robusta
# 5     6    Vietnam  Robusta
# 6     7     Brasil  Robusta
# 7     8  Indonesia  Robusta
#
#                                          description commercial_name
# 0  EXCEPTIONALLY DARK AND CREAMY COFFEE. INTENSIT...       Kenia (A)
# 1     POWERFUL AND CONTRASTING COFFEE. INTENSITY  10      Brasil (A)
# 2  HARMONIOUSLY BALANCED AND THICK BODY COFFEE. I...      Uganda (A)
# 3           POTENT AND ROASTED COFFEE. INTENSITY  10    Colombia (A)
# 4      FRUITY WITH FINE ACIDITY COFFEE. INTENSITY  5    Colombia (R)
# 5             SWEET COFFEE AND CEREALS. INTENSITY  4     Vietnam (R)
# 6         COFFEE WITH ROBUSTA MONSOON. INTENSITY  11      Brasil (R)
# 7                    WET-HULLED COFFEE. INTENSITY  8   Indonesia (R)

# %% [markdown]
# (I.4) Finally, create a new sales dataframe with all the data cleansing processes you may need to upload this data to a sql database.

# %%
sales = result[['name','surname','address','postal_code','city','province','timestamp','type','amount_kg','price_kg','sales_amount']]
sales
# Out:
#         name    surname          address postal_code                city  \
# 0       Cleo   Melendez  Calle U, nº 377       44175              Orrios
# 1      Haley      Rivas  Calle K, nº 369       19095  Condemios de Abajo
# 2     Andrew    Whitley  Calle M, nº 196       47073    Herrín de Campos
# 3     Galvin    Houston  Calle G, nº 355       19166   Málaga del Fresno
# 4         Hu      Brock  Calle T, nº 300       39058             Rasines
# ..       ...        ...              ...         ...                 ...
# 989     Rana  Underwood  Calle B, nº 154       04085            Somontín
# 990   Baxter     Parker   Calle T, nº 32       08219     Vilassar de Mar
# 991  Stephen     Barlow  Calle Q, nº 259       06042              Cheles
# 992    Willa    Mueller  Calle G, nº 244       14018          Carpio, El
# 993  Wyoming     Campos  Calle G, nº 114       22162             Novales
#
#         province           timestamp  type  amount_kg  price_kg  sales_amount
# 0         Teruel 2022-05-10 20:23:47     8       1.25      24.8        31.000
# 1    Guadalajara 2022-02-25 12:22:12     8       0.75      29.2        21.900
# 2     Valladolid 2022-10-16 04:38:07     8       0.75      25.7        19.275
# 3    Guadalajara 2022-08-31 17:58:53     8       5.00      20.3       101.500
# 4      Cantabria 2022-05-16 07:25:14     8       3.00      27.6        82.800
# ..           ...                 ...   ...        ...       ...           ...
# 989      Almería 2022-02-08 04:39:34     5       2.00      24.5        49.000
# 990    Barcelona 2022-10-18 19:25:27     5       0.50      26.0        13.000
# 991      Badajoz 2022-03-15 04:30:30     5       3.00      32.8        98.400
# 992      Córdoba 2022-04-22 00:52:59     5       1.25      15.3        19.125
# 993       Huesca 2022-12-27 15:39:02     5       3.00      31.0        93.000
#
# [994 rows x 11 columns]

# %%
# Saving a copy of the clean 'sales' dataframe in .csv
# so we can load it later as a table in SQLite
sales.to_csv('sales_up.csv')

# We can also create a SQLite table out of our clean upgraded dataframe, as shown 3 cells below.

# %% [markdown]
# ## Part II - SQL Database

# %% [markdown]
# (II.1) You need to create a SQLite database with two tables and load the data from the attached csv files. Make sure all the data has its appropiate data type and that you upload it correctly. First two code blocks import the sqlite module and create the database and its connection.

# %%
import csv
import sqlite3

# %%
# Connecting to the embat database
conn = sqlite3.connect('embat_data')

# Creating a cursor object to execute SQL queries on a database table
c = conn.cursor()

# %%
# Let's create a SQLite table out of our clean (fixed timestamps, dropped NaNs...) and 
# upgraded dataframe (including 'provinces', 'timestamp', 'sales_amount'...)
sales.to_sql(name='sales_update', con=conn)
conn.close()

# %%
# Table Definition
create_table =  '''CREATE TABLE IF NOT EXISTS sales(
    name TEXT NOT NULL,
    surname TEXT NOT NULL,
    address TEXT NOT NULL,
    postal_code TEXT NOT NULL,
    city TEXT NOT NULL,
    timestamp TEXT NOT NULL,
    type INTEGER NOT NULL,
    amount_kg REAL NOT NULL,
    price_kg REAL NOT NULL
    );
    '''

create_table2 =  '''CREATE TABLE IF NOT EXISTS coffee_types(
    type INTEGER NOT NULL,
    country TEXT NOT NULL,
    variety TEXT NOT NULL,
    description TEXT NOT NULL
    );
    '''

# %%
conn = sqlite3.connect('embat_data')
c = conn.cursor()

# Creating the tables into the database
c.execute(create_table)
c.execute(create_table2)

# Opening the 'sales.csv' and 'types.csv' file
file = open('sales.csv')
file2 = open('types.csv')

# Reading the contents of the 'sales.cs'v and 'types.csv' file
contents = csv.reader(file)
contents2 = csv.reader(file2)
 
# SQL query to insert data into the 'sales' table
insert_sales = "INSERT INTO sales (name, surname, address, postal_code, city, timestamp, type, amount_kg, price_kg) VALUES(?, ?, ?, ?, ?, ?, ?, ?, ?)"

# SQL query to insert data into the 'coffee_types' table
insert_coffe_types = "INSERT INTO coffee_types (type, country, variety, description) VALUES(?, ?, ?, ?)"
 
# Importing the contents of the files into our 'sales' and 'coffe_types' table
c.executemany(insert_sales, contents)
c.executemany(insert_coffe_types, contents2)
 
# SQL query to retrieve all data from the sales table to verify that the
# data of the csv file has been successfully inserted into the table
select_5 = "SELECT * FROM sales"
rows = c.execute(select_5).fetchmany(5)

select_5 = "SELECT * FROM coffee_types"
rows2 = c.execute(select_5).fetchmany(5)
 
# Output to the console screen
for r in rows:
    print(r)
print("\n")
for r2 in rows2:
    print(r2)

# Committing changes and closing the database connection:
conn.commit()
conn.close()
# Out:
# ('name', 'surname', 'address', 'postal_code', 'city', 'timestamp', 'coffee_type', 'amount_kg', 'price_kg')
# ('Cleo', 'Melendez', 'Calle U, nº 377', '44175', 'Orrios', '5/10/2022 20:23:47', 8, '1,250', '24,8')
# ('Ryder', 'Mack', 'Calle A, nº 320', '37127', 'Espeja', '31/01/2022 16:52:33', 1, '0,500', '34,8')
# ('Yasir', 'Glover', 'Calle T, nº 31', '10192', 'Torremocha', '31/10/2022 15:16:48', 2, '0,250', '20,4')
# ('Eagan', 'Suarez', 'Calle L, nº 164', '50286', 'Villalba de Perejil', '11/02/2022 3:16:39', 1, '1,000', '31,4')
#
#
# ('type', 'country', 'variety', 'description')
# (1, 'Kenia', 'Arabica', 'EXCEPTIONALLY DARK AND CREAMY COFFEE. INTENSITY  13')
# (2, 'Brasil', 'Arabica', 'POWERFUL AND CONTRASTING COFFEE. INTENSITY  10')
# (3, 'Uganda', 'Arabica', 'HARMONIOUSLY BALANCED AND THICK BODY COFFEE. INTENSITY  8')
# (4, 'Colombia', 'Arabica', 'POTENT AND ROASTED COFFEE. INTENSITY  10')

# %% [markdown]
# (II.2) Answer the same questions solved in (I.1) and (I.2) with sql queries

# %% [markdown]
# (I.1) Answer the following questions related with sales.csv:
# * How many rows and colums do we have? How does our dataframe look like?
# * How many unique values do we have in each column?
# * Statistical values (min, max, avg, deviaton and percentiles) for the amount and the price of the coffee sold.
# * Feel free to add any other information / metrics you may find interesting.

# %%
conn = sqlite3.connect('embat_data')
c = conn.cursor()

# how many rows do we have?
c.execute('SELECT count(*) FROM sales')
rows = c.fetchone()

# how many columns do we have?
data = c.execute('SELECT * FROM sales')
col = len(data.description)

print(f'{rows[0]} rows, {col} columns')

conn.commit() 
conn.close()
# Out:
# 1001 rows, 9 columns

# %%
conn = sqlite3.connect('embat_data')
c = conn.cursor()

# I can keep columns names in a list for:
col_names = []
for column in data.description:
    col_names.append(column[0])

# How many unique values do we have in each column?
print ('UNIQUE VALUES PER COLUMN')
for col in col_names:
    c.execute(f'SELECT COUNT(DISTINCT({col})) FROM sales')
    uniq_values = c.fetchone()[0]
    cadena = '{:<15}{:>5}'.format(col, uniq_values)
    print(cadena)

conn.commit() 
conn.close()
# Out:
# UNIQUE VALUES PER COLUMN
# name             669
# surname          635
# address          961
# postal_code      999
# city            1001
# timestamp       1001
# type              12
# amount_kg         13
# price_kg         202

# %%
conn = sqlite3.connect('embat_data')
c = conn.cursor()

# Statistical values (min, max, avg, deviaton and percentiles) for the amount and the price of the coffee sold.
columnas = ["amount_kg", "price_kg"]

# Preparing the queries:

def statistics(col):
    print(f'\n{col.upper()}')
    q_min = (f'SELECT MIN({col}) FROM sales', 'min')
    q_max = (f'SELECT MAX({col}) FROM sales', 'max')
    q_mean = (f'SELECT ROUND(AVG({col}),3) FROM sales', 'avg')
    calcs = [q_min, q_max, q_mean]
    for calc in calcs:
        c.execute(calc[0])
        value = c.fetchone()[0]
        out = '{:<15}{:>15}'.format(calc[1], value)
        print(out)

for col in columnas:
    statistics(col)


conn.commit() 
conn.close()
# Out:
# AMOUNT_KG
# min                     1500.0
# max                  amount_kg
# avg                      9.573
#
# PRICE_KG
# min                       15.0
# max                   price_kg
# avg                       24.7

# %% [markdown]
# (I.2) Now please load the types.csv and get the following data. Please show the country and coffee variety in the results, not just the type numbers:

# %%
# The total amount of Arabica coffee from Uganda sold in January 2022
# WIP - It's working in 'sales' table (with a trick managing dates), instead of 'sales_update'
conn = sqlite3.connect('embat_data')
c = conn.cursor()

query = '''
        SELECT 
            sales.type, 
            country, 
            variety, 
            SUM (amount_kg)
        FROM 
            sales
        JOIN 
            coffee_types
        ON 
            sales.type = coffee_types.type
        WHERE
            coffee_types.variety = 'Arabica' and
            coffee_types.country = 'Uganda' and
            timestamp LIKE '%/01/%'
            ;
        '''

out = c.execute(query)
for e in out:
    print(e)

conn.commit() 
conn.close()
# Out:
# (3, 'Uganda', 'Arabica', 27.0)

# %%
# The average price of Arabica coffee from Brasil in Q1, Q2, Q3, Q4 2022.
# WIP - Not yet fully solved. Managing timestamps missing.
conn = sqlite3.connect('embat_data')
c = conn.cursor()

query = '''
        SELECT 
            sales_update.type, 
            country, 
            variety, 
            AVG (price_kg)
        FROM 
            sales_update
        JOIN 
            coffee_types
        ON 
            sales_update.type = coffee_types.type
        WHERE
            coffee_types.variety = 'Arabica' and
            coffee_types.country = 'Brasil'
            ;
        '''
#timestamp LIKE '%/01/%'

out = c.execute(query)
for e in out:
    print(e)

conn.commit() 
conn.close()
# Out:
# (2, 'Brasil', 'Arabica', 25.15284552845529)

# %%
conn = sqlite3.connect('embat_data')
c = conn.cursor()

query = '''
        SELECT
            *
        FROM
            sales_update
        ;
        '''
pd.read_sql_query(query, conn)
# Out:
#      index     name    surname          address postal_code  \
# 0        0     Cleo   Melendez  Calle U, nº 377       44175
# 1        1    Haley      Rivas  Calle K, nº 369       19095
# 2        2   Andrew    Whitley  Calle M, nº 196       47073
# 3        3   Galvin    Houston  Calle G, nº 355       19166
# 4        4       Hu      Brock  Calle T, nº 300       39058
# ..     ...      ...        ...              ...         ...
# 989    989     Rana  Underwood  Calle B, nº 154       04085
# 990    990   Baxter     Parker   Calle T, nº 32       08219
# 991    991  Stephen     Barlow  Calle Q, nº 259       06042
# 992    992    Willa    Mueller  Calle G, nº 244       14018
# 993    993  Wyoming     Campos  Calle G, nº 114       22162
#
#                    city     province            timestamp  type  amount_kg  \
# 0                Orrios       Teruel  2022-05-10 20:23:47     8       1.25
# 1    Condemios de Abajo  Guadalajara  2022-02-25 12:22:12     8       0.75
# 2      Herrín de Campos   Valladolid  2022-10-16 04:38:07     8       0.75
# 3     Málaga del Fresno  Guadalajara  2022-08-31 17:58:53     8       5.00
# 4               Rasines    Cantabria  2022-05-16 07:25:14     8       3.00
# ..                  ...          ...                  ...   ...        ...
# 989            Somontín      Almería  2022-02-08 04:39:34     5       2.00
# 990     Vilassar de Mar    Barcelona  2022-10-18 19:25:27     5       0.50
# 991              Cheles      Badajoz  2022-03-15 04:30:30     5       3.00
# 992          Carpio, El      Córdoba  2022-04-22 00:52:59     5       1.25
# 993             Novales       Huesca  2022-12-27 15:39:02     5       3.00
#
#      price_kg  sales_amount
# 0        24.8        31.000
# 1        29.2        21.900
# 2        25.7        19.275
# 3        20.3       101.500
# 4        27.6        82.800
# ..        ...           ...
# 989      24.5        49.000
# 990      26.0        13.000
# 991      32.8        98.400
# 992      15.3        19.125
# 993      31.0        93.000
#
# [994 rows x 12 columns]

# %%
# The total sales amount per source country.

conn = sqlite3.connect('embat_data')
c = conn.cursor()

query = '''
        SELECT
            country,
            SUM(sales_amount) AS total_sales_amount
        FROM
            sales_update
        JOIN
            coffee_types ON sales_update.type = coffee_types.type
        GROUP BY
            country
        ;
        '''
pd.read_sql_query(query, conn)
# Out:
#      country  total_sales_amount
# 0     Brasil           10463.850
# 1   Colombia           11568.500
# 2  Indonesia            6352.675
# 3      Kenia            4805.200
# 4     Uganda            7440.325
# 5    Vietnam            5482.475

# %%
# The total sales amount per shipping address province.
# Using 'sales_update' table.

conn = sqlite3.connect('embat_data')
c = conn.cursor()
query = '''
        SELECT  
            province,
            SUM(sales_amount)
        FROM 
            sales_update
        GROUP BY
            province
        ;
        '''
out = c.execute(query)
for row in out:
    print (row)
conn.commit()
conn.close()
# Out:
# ('Albacete', 302.19999999999993)
# ('Alicante', 934.4250000000001)
# ('Almería', 672.9250000000001)
# ('Asturias', 515.225)
# ('Badajoz', 864.7000000000002)
# ('Baleares', 452.40000000000003)
# ('Barcelona', 2087.7000000000003)
# ('Bizkaia', 629.4749999999999)
# ('Burgos', 2117.85)
# ('Cantabria', 514.5500000000001)
# ('Castellón', 712.85)
# ('Ciudad Real', 562.575)
# ('Coruña', 530.575)
# ('Cuenca', 1841.7500000000002)
# ('Cáceres', 1079.975)
# ('Cádiz', 268.475)
# ('Córdoba', 294.02500000000003)
# ('Gipuzkoa', 598.2)
# ('Girona', 1193.4999999999998)
# ('Granada', 992.725)
# ('Guadalajara', 1406.25)
# ('Huelva', 639.375)
# ('Huesca', 898.825)
# ('Jaén', 690.9)
# ('La Rioja', 1276.925)
# ('Las Palmas', 169.95)
# ('León', 1142.1499999999999)
# ('Lleida', 1731.6)
# ('Lugo', 431.5)
# ('Madrid', 1163.225)
# ('Melilla', 34.375)
# ('Murcia', 298.19999999999993)
# ('Málaga', 487.275)
# ('Navarra', 1389.775)
# ('Not_Found', 320.875)
# ('Ourense', 619.2249999999999)
# ('Palencia', 1203.1750000000002)
# ('Pontevedra', 175.125)
# ('Salamanca', 1626.7749999999999)
# ('Santa Cruz de Tenerife', 327.0)
# ('Segovia', 1078.0)
# ('Sevilla', 472.1499999999999)
# ('Soria', 805.3999999999999)
# ('Tarragona', 875.8750000000001)
# ('Teruel', 984.95)
# ('Toledo', 1050.3999999999999)
# ('Valencia', 1669.8999999999999)
# ('Valladolid', 847.9250000000001)
# ('Zamora', 1705.1249999999998)
# ('Zaragoza', 1292.5249999999999)
# ('Álava', 430.675)
# ('Ávila', 1701.5)

# %%
# In which province did we sell the higher cost orders on average?
# Using 'sales_update' table.

conn = sqlite3.connect('embat_data')
c = conn.cursor()
query = '''
        SELECT  
            province,
            AVG(sales_amount) AS mean
        FROM 
            sales_update
        GROUP BY
            province
        ORDER BY mean DESC
        ;
        '''
out = c.execute(query)
for id, row in enumerate(out):
    if id<5:
        print(row)

conn.commit()
conn.close()
# Out:
# ('Santa Cruz de Tenerife', 65.4)
# ('Huelva', 63.9375)
# ('Cuenca', 63.50862068965518)
# ('Alicante', 62.295)
# ('Lleida', 61.84285714285714)

# %%
# TEST WITH sales_update SQLite table (works)
conn = sqlite3.connect('embat_data')
c = conn.cursor()

query = '''
        SELECT * FROM sales_update
        ;
        '''

out = c.execute(query)
for r in out:
    print(r)
conn.commit()
conn.close()
# Out:
# (0, 'Cleo', 'Melendez', 'Calle U, nº 377', '44175', 'Orrios', 'Teruel', '2022-05-10 20:23:47', 8, 1.25, 24.8, 31.0)
# (1, 'Haley', 'Rivas', 'Calle K, nº 369', '19095', 'Condemios de Abajo', 'Guadalajara', '2022-02-25 12:22:12', 8, 0.75, 29.2, 21.9)
# (2, 'Andrew', 'Whitley', 'Calle M, nº 196', '47073', 'Herrín de Campos', 'Valladolid', '2022-10-16 04:38:07', 8, 0.75, 25.7, 19.275)
# (3, 'Galvin', 'Houston', 'Calle G, nº 355', '19166', 'Málaga del Fresno', 'Guadalajara', '2022-08-31 17:58:53', 8, 5.0, 20.3, 101.5)
# (4, 'Hu', 'Brock', 'Calle T, nº 300', '39058', 'Rasines', 'Cantabria', '2022-05-16 07:25:14', 8, 3.0, 27.6, 82.80000000000001)
# (5, 'Damian', 'Yang', 'Calle V, nº 22', '48913', 'Zierbena', 'Bizkaia', '2022-06-13 02:00:27', 8, 4.0, 28.7, 114.8)
# (6, 'Jason', 'Harding', 'Calle Z, nº 89', '32069', 'Ribadavia', 'Ourense', '2022-03-28 07:14:15', 8, 4.0, 17.0, 68.0)
# (7, 'Amir', 'Barnes', 'Calle D, nº 52', '49024', 'Bóveda de Toro, La', 'Zamora', '2022-03-23 03:52:27', 8, 2.0, 28.1, 56.2)
# (8, 'Alma', 'Watts', 'Calle B, nº 342', '49097', 'Justel', 'Zamora', '2022-05-15 05:01:59', 8, 3.0, 34.1, 102.30000000000001)
# (9, 'Rhoda', 'Mason', 'Calle K, nº 266', '18137', 'Montillana', 'Granada', '2022-12-23 09:45:55', 8, 1.25, 22.1, 27.625)
# (10, 'Dean', 'Blair', 'Calle V, nº 33', '22150', 'Loporzano', 'Huesca', '2022-08-26 08:48:42', 8, 4.0, 15.9, 63.6)
# (11, 'Naida', 'Rogers', 'Calle L, nº 325', '35033', 'Vega de San Mateo', 'Las Palmas', '2022-01-07 11:08:29', 8, 2.0, 29.8, 59.6)
# (12, 'Isaac', 'Dotson', 'Calle J, nº 378', '32035', 'Irixo, O', 'Ourense', '2022-05-01 16:34:30', 8, 1.5, 29.3, 43.95)
# (13, 'Tanner', 'Bailey', 'Calle K, nº 125', '49032', 'Calzadilla de Tera', 'Zamora', '2022-09-05 16:04:29', 8, 1.0, 19.1, 19.1)
# (14, 'Alec', 'Fleming', 'Calle S, nº 113', '47008', 'Almenara de Adaja', 'Valladolid', '2022-10-19 02:41:33', 8, 5.0, 32.2, 161.0)
# (15, 'Thomas', 'Pena', 'Calle F, nº 76', '28001', 'Acebeda, La', 'Madrid', '2022-02-04 00:42:30', 8, 5.0, 29.9, 149.5)
# (16, 'Octavius', 'Snow', 'Calle R, nº 220', '50122', 'Grisel', 'Zaragoza', '2022-06-11 05:57:54', 8, 1.5, 20.9, 31.349999999999998)
# (17, 'Uma', 'Wilkins', 'Calle A, nº 82', '39017', 'Campoo de Yuso', 'Cantabria', '2022-10-21 11:10:45', 8, 0.75, 29.8, 22.35)
# (18, 'Kenneth', 'Glover', 'Calle N, nº 69', '48039', 'Garai', 'Bizkaia', '2022-02-09 21:35:00', 8, 1.0, 18.7, 18.7)
# (19, 'Priscilla', 'Wilson', 'Calle I, nº 348', '45014', 'Añover de Tajo', 'Toledo', '2022-09-30 23:18:23', 8, 0.75, 18.6, 13.950000000000001)
# (20, 'Kane', 'Frazier', 'Calle V, nº 286', '17203', 'Ultramort', 'Girona', '2022-03-20 21:30:02', 8, 1.0, 19.5, 19.5)
# (21, 'Keith', 'Bolton', 'Calle R, nº 213', '19147', 'Huérmeces del Cerro', 'Guadalajara', '2022-04-10 09:10:29', 8, 0.75, 21.9, 16.424999999999997)
# (22, 'Craig', 'Waters', 'Calle Q, nº 269', '11027', 'Puerto de Santa María, El', 'Cádiz', '2022-03-19 11:39:27', 8, 1.25, 15.4, 19.25)
# (23, 'Brent', 'Rosa', 'Calle M, nº 245', '31169', 'Milagro', 'Navarra', '2022-08-10 18:48:41', 8, 2.0, 16.0, 32.0)
# (24, 'Samson', 'Fulton', 'Calle F, nº 222', '52001', 'Melilla', 'Melilla', '2022-02-28 06:30:16', 8, 1.25, 27.5, 34.375)
# (25, 'Silas', 'Newman', 'Calle D, nº 205', '20019', 'Beasain', 'Gipuzkoa', '2022-09-05 10:43:48', 8, 2.0, 24.6, 49.2)
# (26, 'Hop', 'Alvarez', 'Calle Z, nº 317', '24107', 'Pajares de los Oteros', 'León', '2022-08-07 09:14:04', 8, 3.0, 24.6, 73.80000000000001)
# (27, 'Phelan', 'Mays', 'Calle Y, nº 45', '06084', 'Mirandilla', 'Badajoz', '2022-12-05 18:43:50', 8, 3.0, 22.0, 66.0)
# (28, 'Renee', 'Hopper', 'Calle F, nº 249', '02071', 'San Pedro', 'Albacete', '2022-02-13 10:46:21', 8, 1.0, 34.1, 34.1)
# (29, 'Brynn', 'Marsh', 'Calle T, nº 33', '05257', 'Villafranca de la Sierra', 'Ávila', '2022-03-21 05:00:55', 8, 2.0, 27.5, 55.0)
# (30, 'Tate', 'Dale', 'Calle L, nº 200', '46192', 'Petrés', 'Valencia', '2022-10-29 23:50:49', 8, 0.75, 22.0, 16.5)
# (31, 'Joseph', 'Christensen', 'Calle R, nº 119', '40129', 'Montejo de Arévalo', 'Segovia', '2022-01-28 08:23:29', 8, 0.25, 34.8, 8.7)
# (32, 'Asher', 'Cox', 'Calle U, nº 375', '39090', 'Udías', 'Cantabria', '2022-11-20 05:28:36', 8, 1.0, 20.7, 20.7)
# (33, 'Hedy', 'Brewer', 'Calle U, nº 145', '23054', 'Larva', 'Jaén', '2022-07-21 20:47:22', 8, 5.0, 24.0, 120.0)
# (34, 'Elijah', 'Hays', 'Calle D, nº 347', '17112', 'Ogassa', 'Girona', '2022-05-22 04:15:10', 8, 1.0, 30.8, 30.8)
# (35, 'Claudia', 'Le', 'Calle B, nº 319', '17086', 'Jonquera, La', 'Girona', '2022-05-16 13:24:24', 8, 1.25, 23.4, 29.25)
# (36, 'Bell', 'Scott', 'Calle B, nº 161', '41071', 'Paradas', 'Sevilla', '2022-01-19 19:04:29', 8, 0.25, 26.6, 6.65)
# (37, 'Dale', 'George', 'Calle Y, nº 341', '16008', 'Alcalá de la Vega', 'Cuenca', '2022-02-16 05:20:25', 8, 2.0, 33.5, 67.0)
# (38, 'Bert', 'Cain', 'Calle R, nº 60', '16132', 'Mota de Altarejos', 'Cuenca', '2022-09-03 17:37:21', 8, 3.0, 20.0, 60.0)
# (39, 'Coby', 'Huber', 'Calle V, nº 167', '12033', 'Cabanes', 'Castellón', '2022-11-13 01:48:54', 8, 1.25, 26.7, 33.375)
# (40, 'Zachery', 'Humphrey', 'Calle A, nº 360', '10147', 'Piornal', 'Cáceres', '2022-08-13 22:41:39', 8, 0.75, 24.2, 18.15)
# (41, 'Quyn', 'Grimes', 'Calle X, nº 46', '49207', 'Santovenia', 'Zamora', '2022-12-21 06:33:48', 8, 2.0, 34.5, 69.0)
# (42, 'Bruce', 'Ortega', 'Calle M, nº 77', '18023', 'Baza', 'Granada', '2022-11-11 18:47:02', 8, 1.25, 27.1, 33.875)
# (43, 'Clio', 'Vincent', 'Calle B, nº 121', '37101', 'Cerralbo', 'Salamanca', '2022-09-10 23:26:55', 8, 0.5, 22.0, 11.0)
# (44, 'Ferdinand', 'Foreman', 'Calle X, nº 58', '24134', 'Robla, La', 'León', '2022-09-10 07:18:24', 8, 1.5, 33.9, 50.849999999999994)
# (45, 'Shellie', 'Cortez', 'Calle U, nº 122', '43071', 'Horta de Sant Joan', 'Tarragona', '2022-08-23 21:37:02', 8, 0.5, 17.8, 8.9)
# (46, 'David', 'Blackburn', 'Calle J, nº 105', '08167', 'Polinyà', 'Barcelona', '2022-03-26 06:34:21', 8, 1.0, 22.3, 22.3)
# (47, 'Kathleen', 'Wilkinson', 'Calle R, nº 329', '08211', 'Sant Feliu de Llobregat', 'Barcelona', '2022-10-09 22:25:47', 8, 4.0, 30.9, 123.6)
# (48, 'Martin', 'Sims', 'Calle J, nº 257', '09464', 'Villatuelda', 'Burgos', '2022-02-03 14:37:06', 8, 2.0, 24.3, 48.6)
# (49, 'Medge', 'Huff', 'Calle X, nº 317', '49105', 'Maire de Castroponce', 'Zamora', '2022-08-24 02:30:11', 8, 4.0, 26.3, 105.2)
# (50, 'Reese', 'Morgan', 'Calle K, nº 55', '29086', 'Sayalonga', 'Málaga', '2022-02-17 22:48:11', 8, 0.75, 32.4, 24.299999999999997)
# (51, 'Buffy', 'Leonard', 'Calle Q, nº 334', '44141', 'Lledó', 'Teruel', '2022-07-09 15:36:45', 8, 2.0, 23.1, 46.2)
# (52, 'Amity', 'Shepherd', 'Calle I, nº 19', '03135', "Vall d'Ebo, la", 'Alicante', '2022-02-04 20:13:00', 8, 1.5, 23.9, 35.849999999999994)
# (53, 'Carol', 'English', 'Calle W, nº 347', '24176', 'Valdefuentes del Páramo', 'León', '2022-05-25 19:41:09', 8, 0.75, 19.5, 14.625)
# (54, 'Yuli', 'Bates', 'Calle U, nº 347', '46103', 'Quartell', 'Valencia', '2022-09-27 21:00:16', 8, 2.0, 31.5, 63.0)
# (55, 'Adam', 'Moore', 'Calle U, nº 391', '13062', 'Picón', 'Ciudad Real', '2022-10-31 20:22:50', 8, 2.0, 31.2, 62.4)
# (56, 'Aristotle', 'Rivers', 'Calle E, nº 146', '44002', 'Abejuela', 'Teruel', '2022-02-27 03:24:49', 8, 2.0, 19.8, 39.6)
# (57, 'Ayanna', 'Cantu', 'Calle V, nº 23', '45079', 'Iglesuela del Tiétar, La', 'Toledo', '2022-06-27 17:16:37', 8, 0.5, 24.1, 12.05)
# (58, 'Xena', 'Horne', 'Calle H, nº 179', '50105', 'Fayón', 'Zaragoza', '2022-02-06 05:00:16', 8, 1.5, 21.4, 32.099999999999994)
# (59, 'Barry', 'Cleveland', 'Calle N, nº 336', '17094', 'Llívia', 'Girona', '2022-07-16 00:39:59', 8, 2.0, 34.8, 69.6)
# (60, 'Josephine', 'Perkins', 'Calle O, nº 254', '40074', 'Escarabajosa de Cabezas', 'Segovia', '2022-07-29 08:00:05', 8, 2.0, 24.4, 48.8)
# (61, 'Bethany', 'Norman', 'Calle L, nº 313', '16043', 'Campillos-Paravientos', 'Cuenca', '2022-02-21 15:55:29', 8, 1.0, 24.0, 24.0)
# (62, 'Madeline', 'Vega', 'Calle Y, nº 190', '02016', 'Bienservida', 'Albacete', '2022-12-08 13:01:29', 8, 1.25, 19.7, 24.625)
# (63, 'Jamal', 'Solis', 'Calle F, nº 386', '49173', 'Rábano de Aliste', 'Zamora', '2022-03-22 01:55:14', 8, 3.0, 19.2, 57.599999999999994)
# (64, 'Gavin', 'Beasley', 'Calle B, nº 46', '43142', 'Sarral', 'Tarragona', '2022-03-02 23:49:18', 8, 1.25, 32.2, 40.25)
# (65, 'Clayton', 'Espinoza', 'Calle P, nº 58', '26178', 'Viniegra de Abajo', 'La Rioja', '2022-11-26 05:58:34', 8, 1.25, 31.5, 39.375)
# (66, 'Fuller', 'Chase', 'Calle Q, nº 77', '44148', 'Mezquita de Jarque', 'Teruel', '2022-10-03 06:33:21', 8, 3.0, 27.4, 82.19999999999999)
# (67, 'Ursula', 'Riddle', 'Calle F, nº 400', '28150', 'Torrejón de Velasco', 'Madrid', '2022-07-08 19:11:47', 8, 1.0, 33.3, 33.3)
# (68, 'Octavia', 'Shepard', 'Calle S, nº 162', '10161', 'Ruanes', 'Cáceres', '2022-05-14 23:58:07', 8, 4.0, 26.9, 107.6)
# (69, 'Amir', 'Malone', 'Calle N, nº 29', '29054', 'Fuengirola', 'Málaga', '2022-04-08 10:11:32', 8, 2.0, 23.6, 47.2)
# (70, 'Luke', 'Harding', 'Calle I, nº 14', '44226', 'Torrelacárcel', 'Teruel', '2022-01-21 23:00:42', 8, 4.0, 17.6, 70.4)
# (71, 'Russell', 'Carson', 'Calle C, nº 36', '01023', 'Elvillar/Bilar', 'Álava', '2022-07-24 00:44:21', 8, 4.0, 30.1, 120.4)
# (72, 'William', 'Peck', 'Calle X, nº 298', '45143', 'Quismondo', 'Toledo', '2022-02-24 09:11:01', 8, 3.0, 23.2, 69.6)
# (73, 'Isaac', 'Bradshaw', 'Calle X, nº 323', '18154', 'Peza, La', 'Granada', '2022-09-12 12:07:34', 8, 1.25, 28.3, 35.375)
# (74, 'Erich', 'Page', 'Calle T, nº 16', '08111', 'Malla', 'Barcelona', '2022-12-16 00:56:39', 8, 1.25, 26.0, 32.5)
# (75, 'Solomon', 'Huber', 'Calle U, nº 66', '46235', 'Sueca', 'Valencia', '2022-08-14 20:16:40', 8, 2.0, 28.6, 57.2)
# (76, 'Judah', 'Rocha', 'Calle W, nº 66', '17036', 'Campdevànol', 'Girona', '2022-10-06 05:33:53', 8, 2.0, 24.3, 48.6)
# (77, 'Sierra', 'Guzman', 'Calle S, nº 324', '16191', 'San Lorenzo de la Parrilla', 'Cuenca', '2022-04-08 11:50:36', 8, 3.0, 33.3, 99.89999999999999)
# (78, 'Finn', 'Roberts', 'Calle S, nº 166', '37351', 'Villaflores', 'Salamanca', '2022-09-20 01:37:09', 8, 0.5, 25.0, 12.5)
# (79, 'Cooper', 'Pace', 'Calle X, nº 313', '29077', 'Parauta', 'Málaga', '2022-11-17 00:31:40', 8, 1.25, 26.6, 33.25)
# (80, 'Carolyn', 'Conner', 'Calle D, nº 11', '08174', 'Puigdàlber', 'Barcelona', '2022-02-21 06:42:55', 8, 0.75, 21.8, 16.35)
# (81, 'Desiree', 'Bush', 'Calle A, nº 24', '34053', 'Castromocho', 'Palencia', '2022-12-03 13:08:33', 8, 4.0, 30.0, 120.0)
# (82, 'Walter', 'Burt', 'Calle P, nº 314', '31123', 'Uharte Arakil', 'Navarra', '2022-03-26 05:44:05', 8, 1.0, 19.3, 19.3)
# (83, 'Francis', 'Mann', 'Calle N, nº 177', '18185', 'Ventas de Huelma', 'Granada', '2022-07-23 14:00:39', 8, 1.5, 24.7, 37.05)
# (84, 'Ingrid', 'Peck', 'Calle N, nº 112', '25118', 'Juncosa', 'Lleida', '2022-05-16 17:26:56', 8, 3.0, 23.2, 69.6)
# (85, 'Brenna', 'Simmons', 'Calle Z, nº 116', '30030', 'Murcia', 'Murcia', '2022-02-13 11:54:09', 8, 4.0, 34.3, 137.2)
# (86, 'Kevin', 'Holcomb', 'Calle N, nº 348', '45095', 'Mata, La', 'Toledo', '2022-09-21 18:43:22', 8, 0.5, 19.8, 9.9)
# (87, 'Beverly', 'Lang', 'Calle Y, nº 59', '42132', 'Noviercas', 'Soria', '2022-11-24 01:17:50', 8, 1.5, 19.8, 29.700000000000003)
# (88, 'Troy', 'Carson', 'Calle C, nº 212', '44257', 'Villar del Cobo', 'Teruel', '2022-11-06 19:36:03', 8, 1.25, 31.8, 39.75)
# (89, 'Simone', 'Farrell', 'Calle T, nº 215', '50229', 'Ruesca', 'Zaragoza', '2022-03-16 22:56:28', 8, 0.25, 15.3, 3.825)
# (90, 'Preston', 'Marsh', 'Calle G, nº 120', '10034', 'Cabezabellosa', 'Cáceres', '2022-11-23 21:08:58', 8, 1.0, 19.2, 19.2)
# (91, 'Karen', 'Harding', 'Calle G, nº 144', '08118', 'Masnou, El', 'Barcelona', '2022-10-25 13:48:14', 8, 3.0, 18.8, 56.400000000000006)
# (92, 'Hadassah', 'Gates', 'Calle M, nº 143', '20035', 'Ezkio-Itsaso', 'Gipuzkoa', '2022-07-23 14:23:22', 8, 2.0, 23.5, 47.0)
# (93, 'Dawn', 'Gardner', 'Calle X, nº 229', '25239', 'Valls de Valira, Les', 'Lleida', '2022-06-23 05:02:29', 8, 1.0, 24.8, 24.8)
# (94, 'Wallace', 'Weber', 'Calle I, nº 366', '49127', 'Morales del Vino', 'Zamora', '2022-03-14 21:49:08', 8, 1.25, 26.2, 32.75)
# (95, 'Hilary', 'Horne', 'Calle V, nº 140', '16025', 'Arrancacepas', 'Cuenca', '2022-02-25 02:36:29', 8, 4.0, 18.0, 72.0)
# (96, 'Zia', 'Whitney', 'Calle E, nº 172', '23029', 'Chiclana de Segura', 'Jaén', '2022-04-14 13:32:02', 8, 4.0, 26.4, 105.6)
# (97, 'Charity', 'Frank', 'Calle S, nº 387', '40063', 'Cuéllar', 'Segovia', '2022-12-21 19:05:25', 8, 5.0, 21.0, 105.0)
# (98, 'Hall', 'Weiss', 'Calle F, nº 118', '48904', 'Sondika', 'Bizkaia', '2022-01-07 17:57:26', 8, 0.75, 16.4, 12.299999999999999)
# (99, 'Lionel', 'Rowland', 'Calle F, nº 233', '26126', 'Robres del Castillo', 'La Rioja', '2022-08-31 12:38:54', 8, 1.5, 22.6, 33.900000000000006)
# (100, 'Garrett', 'Holt', 'Calle I, nº 172', '06029', 'Campillo de Llerena', 'Badajoz', '2022-08-18 19:56:41', 8, 0.5, 18.9, 9.45)
# (101, 'Bethany', 'Parks', 'Calle M, nº 102', '28025', 'Brea de Tajo', 'Madrid', '2022-06-18 11:16:29', 8, 3.0, 22.7, 68.1)
# (102, 'Hadley', 'Perry', 'Calle R, nº 228', '04004', 'Albanchez', 'Almería', '2022-12-11 02:15:22', 8, 4.0, 25.8, 103.2)
# (103, 'Luke', 'Mclaughlin', 'Calle W, nº 92', '08226', 'Sant Martí de Tous', 'Barcelona', '2022-01-27 01:16:03', 8, 0.25, 17.2, 4.3)
# (104, 'Karina', 'Brown', 'Calle L, nº 206', '24154', 'Santa Elena de Jamuz', 'León', '2022-12-27 23:34:30', 8, 0.5, 30.5, 15.25)
# (105, 'Tana', 'Roth', 'Calle C, nº 104', '03113', 'Rojales', 'Alicante', '2022-11-23 18:17:40', 8, 1.0, 32.9, 32.9)
# (106, 'Madeline', 'Carney', 'Calle N, nº 221', '49088', 'Gamones', 'Zamora', '2022-11-06 23:18:09', 8, 1.0, 31.4, 31.4)
# (107, 'Tamekah', 'Cardenas', 'Calle Y, nº 252', '06005', 'Albuera, La', 'Badajoz', '2022-05-13 12:38:15', 8, 0.75, 20.9, 15.674999999999999)
# (108, 'Savannah', 'Mcclure', 'Calle X, nº 384', '17078', 'Ger', 'Girona', '2022-09-25 19:42:58', 8, 0.75, 27.2, 20.4)
# (109, 'Hasad', 'Holmes', 'Calle Y, nº 45', '17178', 'Sant Pere Pescador', 'Girona', '2022-12-15 20:09:51', 8, 3.0, 24.5, 73.5)
# (110, 'Perry', 'Marshall', 'Calle F, nº 241', '32077', 'Sandiás', 'Ourense', '2022-07-20 17:37:21', 8, 5.0, 20.5, 102.5)
# (111, 'Baxter', 'Palmer', 'Calle S, nº 92', '37091', 'Casillas de Flores', 'Salamanca', '2022-02-09 04:58:20', 8, 4.0, 33.5, 134.0)
# (112, 'Nevada', 'Hunt', 'Calle G, nº 213', '45191', 'Villamuelas', 'Toledo', '2022-11-26 20:39:55', 8, 1.5, 22.8, 34.2)
# (113, 'Thaddeus', 'Gill', 'Calle G, nº 114', '09162', 'Hontoria de la Cantera', 'Burgos', '2022-03-01 17:12:08', 8, 1.25, 31.7, 39.625)
# (114, 'Malcolm', 'Bauer', 'Calle X, nº 335', '49156', 'Pinilla de Toro', 'Zamora', '2022-04-27 09:43:03', 8, 2.0, 26.4, 52.8)
# (115, 'Zia', 'Meadows', 'Calle J, nº 149', '16060', 'Casas de Benítez', 'Cuenca', '2022-04-08 19:14:37', 8, 1.5, 25.7, 38.55)
# (116, 'Keiko', 'Baker', 'Calle J, nº 205', '37168', 'Lagunilla', 'Salamanca', '2022-03-30 08:34:24', 8, 0.25, 23.5, 5.875)
# (117, 'Ryder', 'Griffith', 'Calle Y, nº 104', '50031', 'Aranda de Moncayo', 'Zaragoza', '2022-02-01 13:55:46', 8, 2.0, 20.7, 41.4)
# (118, 'Adele', 'Short', 'Calle V, nº 334', '28052', 'Chinchón', 'Madrid', '2022-04-15 07:28:00', 8, 0.75, 30.6, 22.950000000000003)
# (119, 'Kiona', 'Craft', 'Calle L, nº 226', '45063', 'Espinoso del Rey', 'Toledo', '2022-09-30 04:37:02', 8, 0.5, 17.1, 8.55)
# (120, 'Justine', 'Cervantes', 'Calle Z, nº 298', '37160', 'Hinojosa de Duero', 'Salamanca', '2022-03-14 10:14:51', 8, 1.5, 29.7, 44.55)
# (121, 'Clio', 'Bell', 'Calle J, nº 307', '21023', 'Cerro de Andévalo, El', 'Huelva', '2022-01-01 05:42:44', 8, 1.5, 17.8, 26.700000000000003)
# (122, 'Constance', 'Fuentes', 'Calle V, nº 22', '20057', 'Mutiloa', 'Gipuzkoa', '2022-02-20 19:44:35', 8, 0.25, 34.9, 8.725)
# (123, 'Ori', 'Larson', 'Calle T, nº 124', '07902', 'Migjorn Gran, Es', 'Baleares', '2022-11-30 08:00:40', 8, 1.0, 26.6, 26.6)
# (124, 'Micah', 'Buckner', 'Calle U, nº 283', '10010', 'Alcuéscar', 'Cáceres', '2022-04-12 09:54:03', 8, 1.5, 22.0, 33.0)
# (125, 'Kadeem', 'Pate', 'Calle Y, nº 284', '43079', 'Masllorenç', 'Tarragona', '2022-06-15 21:20:46', 8, 2.0, 17.3, 34.6)
# (126, 'Rogan', 'Landry', 'Calle U, nº 94', '37236', 'Pedrosillo de Alba', 'Salamanca', '2022-08-12 02:37:16', 8, 1.25, 33.2, 41.5)
# (127, 'Sandra', 'Young', 'Calle F, nº 356', '23047', 'Iruela, La', 'Jaén', '2022-10-22 14:31:07', 8, 0.5, 21.2, 10.6)
# (128, 'Azalia', 'Pittman', 'Calle W, nº 295', '25903', "Guingueta d'Àneu, La", 'Lleida', '2022-08-05 07:17:11', 8, 1.5, 30.2, 45.3)
# (129, 'August', 'Marks', 'Calle U, nº 15', '42212', 'Villasayas', 'Soria', '2022-08-24 09:45:42', 8, 0.5, 27.1, 13.55)
# (130, 'Yen', 'Vincent', 'Calle G, nº 156', '10200', 'Valdelacasa de Tajo', 'Cáceres', '2022-10-31 18:14:42', 8, 0.75, 31.5, 23.625)
# (131, 'Yoshi', 'Avery', 'Calle O, nº 115', '37325', 'Tornadizo, El', 'Salamanca', '2022-12-05 16:50:30', 8, 1.25, 33.7, 42.125)
# (132, 'Clare', 'Combs', 'Calle L, nº 139', '44052', 'Calomarde', 'Teruel', '2022-01-19 07:15:12', 8, 1.5, 26.9, 40.349999999999994)
# (133, 'Priscilla', 'Blake', 'Calle G, nº 193', '04062', 'Macael', 'Almería', '2022-03-04 10:10:14', 8, 3.0, 20.4, 61.199999999999996)
# (134, 'Maxwell', 'Carter', 'Calle S, nº 294', '32045', 'Maside', 'Ourense', '2022-04-06 15:38:56', 8, 1.0, 26.0, 26.0)
# (135, 'Athena', 'Michael', 'Calle E, nº 35', '48026', 'Dima', 'Bizkaia', '2022-10-02 16:07:34', 8, 1.5, 34.0, 51.0)
# (136, 'Ryder', 'Mack', 'Calle A, nº 320', '37127', 'Espeja', 'Salamanca', '2022-01-31 16:52:33', 1, 0.5, 34.8, 17.4)
# (137, 'Eagan', 'Suarez', 'Calle L, nº 164', '50286', 'Villalba de Perejil', 'Zaragoza', '2022-11-02 03:16:39', 1, 1.0, 31.4, 31.4)
# (138, 'Kimberly', 'Farmer', 'Calle K, nº 229', '48079', 'Errigoiti', 'Bizkaia', '2022-02-22 12:09:00', 1, 0.75, 24.2, 18.15)
# (139, 'Mona', 'Frank', 'Calle H, nº 196', '46203', 'Pobla Llarga, la', 'Valencia', '2022-05-06 22:54:48', 1, 4.0, 20.5, 82.0)
# (140, 'Steel', 'Johnston', 'Calle Q, nº 63', '02048', 'Minaya', 'Albacete', '2022-10-27 08:27:52', 1, 0.5, 29.1, 14.55)
# (141, 'Zane', 'Weaver', 'Calle G, nº 33', '17070', 'Fontanilles', 'Girona', '2022-03-25 05:20:03', 1, 0.5, 30.7, 15.35)
# (142, 'Adena', 'Barrera', 'Calle P, nº 193', '26018', 'Arnedo', 'La Rioja', '2022-09-11 20:31:36', 1, 4.0, 24.4, 97.6)
# (143, 'Meredith', 'Velasquez', 'Calle D, nº 301', '09433', 'Villagalijo', 'Burgos', '2022-06-21 07:08:59', 1, 0.75, 20.7, 15.524999999999999)
# (144, 'August', 'Jarvis', 'Calle D, nº 395', '04069', 'Olula del Río', 'Almería', '2022-10-14 19:36:25', 1, 1.25, 17.7, 22.125)
# (145, 'Diana', 'Rodriguez', 'Calle G, nº 376', '48051', 'Lanestosa', 'Bizkaia', '2022-08-23 03:42:44', 1, 1.5, 23.8, 35.7)
# (146, 'Penelope', 'Adkins', 'Calle I, nº 121', '16251', 'Villanueva de la Jara', 'Cuenca', '2022-10-11 08:05:28', 1, 1.25, 23.5, 29.375)
# (147, 'Sean', 'Roy', 'Calle U, nº 111', '42082', 'Estepa de San Juan', 'Soria', '2022-04-16 23:18:13', 1, 0.25, 15.2, 3.8)
# (148, 'Tucker', 'Dillon', 'Calle A, nº 195', '03117', 'Sanet y Negrals', 'Alicante', '2022-12-02 20:52:22', 1, 5.0, 27.4, 137.0)
# (149, 'Justin', 'Goodwin', 'Calle Z, nº 133', '28141', 'Sevilla la Nueva', 'Madrid', '2022-08-09 01:26:40', 1, 1.5, 19.5, 29.25)
# (150, 'Adam', 'Barrett', 'Calle K, nº 193', '27045', 'Pedrafita do Cebreiro', 'Lugo', '2022-12-20 09:28:33', 1, 0.75, 30.4, 22.799999999999997)
# (151, 'Axel', 'Houston', 'Calle B, nº 77', '18005', 'Albuñán', 'Granada', '2022-03-14 15:11:21', 1, 0.75, 25.3, 18.975)
# (152, 'Howard', 'Ortiz', 'Calle R, nº 10', '16906', 'Valdecolmenas, Los', 'Cuenca', '2022-04-06 21:19:59', 1, 5.0, 30.9, 154.5)
# (153, 'Ifeoma', 'House', 'Calle W, nº 291', '07064', 'Castell, Es', 'Baleares', '2022-06-28 17:19:37', 1, 1.0, 15.1, 15.1)
# (154, 'Kane', 'Brady', 'Calle D, nº 55', '24082', 'Hospital de Órbigo', 'León', '2022-12-28 10:40:29', 1, 1.25, 34.9, 43.625)
# (155, 'Colton', 'Hill', 'Calle A, nº 116', '49059', 'Cuelgamures', 'Zamora', '2022-11-11 22:01:21', 1, 0.75, 21.6, 16.200000000000003)
# (156, 'Dorian', 'Schultz', 'Calle N, nº 301', '03010', 'Alfafara', 'Alicante', '2022-07-24 10:06:33', 1, 2.0, 31.9, 63.8)
# (157, 'Zenaida', 'Jefferson', 'Calle W, nº 319', '46065', 'Beniparrell', 'Valencia', '2022-04-17 22:32:17', 1, 0.25, 22.6, 5.65)
# (158, 'Laura', 'Lewis', 'Calle D, nº 26', '25057', 'Bòrdes, Es', 'Lleida', '2022-07-19 21:03:31', 1, 4.0, 17.8, 71.2)
# (159, 'Armando', 'Sparks', 'Calle L, nº 22', '19226', 'Prádena de Atienza', 'Guadalajara', '2022-07-28 06:44:05', 1, 1.0, 31.5, 31.5)
# (160, 'Jack', 'Lewis', 'Calle J, nº 34', '47032', 'Camporredondo', 'Valladolid', '2022-09-18 06:09:59', 1, 0.5, 16.7, 8.35)
# (161, 'Nevada', 'Holland', 'Calle K, nº 168', '43907', 'Canonja, La', 'Tarragona', '2022-08-08 21:30:09', 1, 1.0, 16.8, 16.8)
# (162, 'Jemima', 'Clayton', 'Calle X, nº 237', '48092', 'Bedia', 'Bizkaia', '2022-12-24 01:46:38', 1, 2.0, 28.2, 56.4)
# (163, 'Lee', 'Bartlett', 'Calle K, nº 51', '48045', 'Güeñes', 'Bizkaia', '2022-10-28 03:52:10', 1, 4.0, 28.4, 113.6)
# (164, 'Baxter', 'Lloyd', 'Calle B, nº 54', '28117', 'Prádena del Rincón', 'Madrid', '2022-05-04 11:53:51', 1, 3.0, 19.0, 57.0)
# (165, 'Jennifer', 'Hunt', 'Calle J, nº 283', '16034', 'Belmontejo', 'Cuenca', '2022-09-06 18:27:16', 1, 0.5, 32.4, 16.2)
# (166, 'Elizabeth', 'Guzman', 'Calle B, nº 313', '50277', 'Valtorres', 'Zaragoza', '2022-04-11 03:47:22', 1, 1.0, 31.2, 31.2)
# (167, 'Steel', 'Atkinson', 'Calle H, nº 114', '09223', 'Monasterio de la Sierra', 'Burgos', '2022-04-06 16:59:57', 1, 0.75, 25.9, 19.424999999999997)
# (168, 'Herman', 'Fisher', 'Calle S, nº 316', '42202', 'Velilla de los Ajos', 'Soria', '2022-10-24 14:53:28', 1, 2.0, 16.1, 32.2)
# (169, 'Felix', 'Hobbs', 'Calle X, nº 363', '46002', 'Ador', 'Valencia', '2022-12-26 08:41:05', 1, 4.0, 16.9, 67.6)
# (170, 'Buffy', 'Navarro', 'Calle A, nº 192', '21063', 'San Bartolomé de la Torre', 'Huelva', '2022-07-13 12:43:41', 1, 1.25, 26.1, 32.625)
# (171, 'Yuli', 'Rivera', 'Calle O, nº 66', '37184', 'Masueco', 'Salamanca', '2022-09-13 01:01:59', 1, 1.25, 33.6, 42.0)
# (172, 'Regan', 'Potts', 'Calle E, nº 185', '08052', "Castellar de n'Hug", 'Barcelona', '2022-09-15 18:33:26', 1, 5.0, 27.7, 138.5)
# (173, 'Sybil', 'Saunders', 'Calle G, nº 381', '28109', 'Pelayos de la Presa', 'Madrid', '2022-11-13 00:43:56', 1, 1.0, 31.4, 31.4)
# (174, 'Brady', 'Collins', 'Calle W, nº 93', '19066', 'Cañizar', 'Guadalajara', '2022-09-16 13:28:32', 1, 2.0, 31.8, 63.6)
# (175, 'Jeanette', 'Stein', 'Calle O, nº 89', '37244', 'Peñacaballera', 'Salamanca', '2022-03-08 13:46:25', 1, 1.25, 21.3, 26.625)
# (176, 'Cairo', 'Meadows', 'Calle P, nº 296', '31083', 'Echarri/Etxarri', 'Navarra', '2022-05-23 20:22:33', 1, 3.0, 16.3, 48.900000000000006)
# (177, 'Stuart', 'Klein', 'Calle A, nº 285', '11011', 'Bosque, El', 'Cádiz', '2022-06-20 14:16:57', 1, 0.25, 25.1, 6.275)
# (178, 'Cruz', 'Compton', 'Calle C, nº 142', '05140', 'Muñomer del Peco', 'Ávila', '2022-04-15 08:35:41', 1, 1.0, 28.4, 28.4)
# (179, 'Derek', 'Garrett', 'Calle T, nº 312', '16211', 'Torrejoncillo del Rey', 'Cuenca', '2022-07-01 00:15:21', 1, 1.5, 17.2, 25.799999999999997)
# (180, 'Noble', 'Finch', 'Calle C, nº 317', '17163', 'Sant Gregori', 'Girona', '2022-12-16 06:43:48', 1, 1.0, 31.3, 31.3)
# (181, 'Jaden', 'Stark', 'Calle Q, nº 85', '35025', 'Tejeda', 'Las Palmas', '2022-04-21 16:48:31', 1, 0.5, 23.2, 11.6)
# (182, 'Herrod', 'Contreras', 'Calle L, nº 1', '37176', 'Madroñal', 'Salamanca', '2022-11-18 17:02:41', 1, 0.75, 24.4, 18.299999999999997)
# (183, 'Chanda', 'Hull', 'Calle K, nº 114', '09018', 'Aranda de Duero', 'Burgos', '2022-07-18 20:08:17', 1, 1.25, 19.6, 24.5)
# (184, 'Christian', 'Cobb', 'Calle B, nº 289', '08004', 'Alpens', 'Barcelona', '2022-02-25 12:28:47', 1, 0.25, 22.3, 5.575)
# (185, 'Dane', 'Hunt', 'Calle D, nº 50', '40103', 'Huertos, Los', 'Segovia', '2022-07-23 09:49:45', 1, 3.0, 35.0, 105.0)
# (186, 'Madison', 'Bryan', 'Calle P, nº 97', '05174', 'Orbita', 'Ávila', '2022-04-20 06:09:32', 1, 1.25, 18.3, 22.875)
# (187, 'Buckminster', "O'donnell", 'Calle D, nº 269', '16264', 'Villarejo de Fuentes', 'Cuenca', '2022-03-22 06:24:56', 1, 3.0, 32.2, 96.60000000000001)
# (188, 'Roth', 'Dyer', 'Calle H, nº 239', '37054', 'Bodón, El', 'Salamanca', '2022-07-06 05:08:47', 1, 0.25, 28.0, 7.0)
# (189, 'Jin', 'Mckenzie', 'Calle C, nº 342', '28099', 'Navas del Rey', 'Madrid', '2022-08-24 14:37:10', 1, 2.0, 20.4, 40.8)
# (190, 'Shafira', 'Watts', 'Calle T, nº 170', '05247', 'Torre, La', 'Ávila', '2022-01-08 06:32:52', 1, 4.0, 25.4, 101.6)
# (191, 'Oscar', 'Carey', 'Calle F, nº 285', '34045', 'Capillas', 'Palencia', '2022-11-21 19:38:53', 1, 1.0, 25.0, 25.0)
# (192, 'Grant', 'Mcconnell', 'Calle T, nº 297', '25164', 'Penelles', 'Lleida', '2022-05-28 07:44:20', 1, 5.0, 22.9, 114.5)
# (193, 'Keiko', 'Pena', 'Calle Y, nº 84', '37018', 'Aldeanueva de la Sierra', 'Salamanca', '2022-06-06 15:40:36', 1, 1.5, 31.0, 46.5)
# (194, 'Madeline', 'Stone', 'Calle I, nº 139', '21007', 'Aracena', 'Huelva', '2022-05-22 07:41:47', 1, 1.5, 25.9, 38.849999999999994)
# (195, 'Beatrice', 'Harrison', 'Calle M, nº 160', '04054', 'Íllar', 'Almería', '2022-12-08 17:02:06', 1, 3.0, 18.2, 54.599999999999994)
# (196, 'Nolan', 'Bryant', 'Calle Y, nº 166', '20081', 'Zumaia', 'Gipuzkoa', '2022-06-30 16:19:07', 1, 1.25, 26.4, 33.0)
# (197, 'Dante', 'Pacheco', 'Calle D, nº 41', '31139', 'Lana', 'Navarra', '2022-03-31 19:23:24', 1, 0.25, 21.2, 5.3)
# (198, 'Colin', 'Fowler', 'Calle F, nº 333', '42061', 'Cidones', 'Soria', '2022-06-09 19:35:21', 1, 0.25, 22.8, 5.7)
# (199, 'Asher', 'Solomon', 'Calle R, nº 198', '08300', 'Viladecavalls', 'Barcelona', '2022-09-15 00:57:46', 1, 4.0, 20.5, 82.0)
# (200, 'Macon', 'Grimes', 'Calle D, nº 34', '22223', 'Sopeira', 'Huesca', '2022-10-19 07:31:16', 1, 2.0, 16.2, 32.4)
# (201, 'Clayton', 'Russo', 'Calle R, nº 18', '18015', 'Alicún de Ortega', 'Granada', '2022-03-29 06:09:25', 1, 0.5, 34.6, 17.3)
# (202, 'Harriet', 'Pruitt', 'Calle P, nº 385', '09387', 'Torregalindo', 'Burgos', '2022-04-17 02:24:14', 1, 5.0, 22.2, 111.0)
# (203, 'Orson', 'Walton', 'Calle O, nº 108', '03098', 'Orxeta', 'Alicante', '2022-05-02 02:08:25', 1, 0.25, 21.6, 5.4)
# (204, 'Darius', 'Gould', 'Calle R, nº 262', '17046', 'Castellfollit de la Roca', 'Girona', '2022-12-30 20:09:29', 1, 2.0, 26.3, 52.6)
# (205, 'Sean', 'Ross', 'Calle I, nº 134', '06138', 'Valdetorres', 'Badajoz', '2022-01-23 04:19:54', 1, 1.5, 27.6, 41.400000000000006)
# (206, 'Sade', 'Riggs', 'Calle C, nº 24', '03083', 'Jijona/Xixona', 'Alicante', '2022-01-08 10:41:56', 1, 0.75, 18.1, 13.575000000000001)
# (207, 'Rowan', 'Hardin', 'Calle O, nº 105', '31261', 'Yesa', 'Navarra', '2022-07-21 16:16:52', 1, 0.5, 33.6, 16.8)
# (208, 'Carolyn', 'Pollard', 'Calle U, nº 22', '31200', 'Oteiza', 'Navarra', '2022-10-13 18:38:45', 1, 1.0, 18.8, 18.8)
# (209, 'Kyle', 'Tucker', 'Calle P, nº 255', '41026', 'Casariche', 'Sevilla', '2022-06-22 13:21:26', 1, 1.0, 23.4, 23.4)
# (210, 'Nola', 'Sargent', 'Calle E, nº 115', '30006', 'Aledo', 'Murcia', '2022-05-06 18:12:11', 1, 4.0, 25.8, 103.2)
# (211, 'Hammett', 'Ratliff', 'Calle O, nº 289', '47048', 'Ceinos de Campos', 'Valladolid', '2022-08-10 02:25:55', 1, 0.75, 19.1, 14.325000000000001)
# (212, 'Cassandra', 'Haynes', 'Calle D, nº 357', '18164', 'Puebla de Don Fadrique', 'Granada', '2022-10-15 09:36:15', 1, 0.75, 34.8, 26.099999999999998)
# (213, 'Georgia', 'Parker', 'Calle J, nº 3', '49068', 'Ferreruela', 'Zamora', '2022-01-06 17:27:29', 1, 1.25, 18.6, 23.25)
# (214, 'Steel', 'Blackwell', 'Calle K, nº 223', '30037', 'Torre-Pacheco', 'Murcia', '2022-08-17 14:01:33', 1, 0.25, 26.0, 6.5)
# (215, 'MacKenzie', 'Ramirez', 'Calle B, nº 264', '25232', 'Torres de Segre', 'Lleida', '2022-02-20 07:23:57', 1, 4.0, 20.3, 81.2)
# (216, 'Sarah', 'Fleming', 'Calle U, nº 91', '37201', 'Montemayor del Río', 'Salamanca', '2022-01-17 21:12:14', 1, 0.5, 23.1, 11.55)
# (217, 'Tamara', 'Larson', 'Calle C, nº 106', '43063', 'Galera, La', 'Tarragona', '2022-09-28 13:05:43', 1, 0.5, 15.8, 7.9)
# (218, 'Yuli', 'Mcgowan', 'Calle S, nº 212', '34072', 'Frechilla', 'Palencia', '2022-05-03 19:38:19', 1, 4.0, 30.3, 121.2)
# (219, 'Cameron', 'Gillespie', 'Calle C, nº 56', '50204', 'Pedrola', 'Zaragoza', '2022-05-09 07:03:58', 1, 0.25, 18.2, 4.55)
# (220, 'Sasha', 'Witt', 'Calle M, nº 16', '13054', 'Membrilla', 'Ciudad Real', '2022-04-08 05:21:59', 1, 1.25, 31.6, 39.5)
# (221, 'Alfreda', 'Mosley', 'Calle E, nº 239', '43157', 'Ulldemolins', 'Tarragona', '2022-06-02 03:45:24', 1, 0.75, 23.4, 17.549999999999997)
# (222, 'Latifah', 'Gentry', 'Calle D, nº 169', '47231', 'Zaratán', 'Valladolid', '2022-02-13 16:29:42', 1, 2.0, 30.2, 60.4)
# (223, 'Macon', 'Rodriquez', 'Calle P, nº 18', '15029', 'Coristanco', 'Coruña', '2022-01-24 02:47:10', 1, 2.0, 26.8, 53.6)
# (224, 'Octavia', 'Caldwell', 'Calle D, nº 75', '41041', 'Estepa', 'Sevilla', '2022-06-08 21:09:21', 1, 2.0, 24.7, 49.4)
# (225, 'Adara', 'Holden', 'Calle P, nº 254', '19304', 'Valdenuño Fernández', 'Guadalajara', '2022-05-12 07:05:44', 1, 0.5, 27.9, 13.95)
# (226, 'Dieter', 'Hutchinson', 'Calle J, nº 31', '09352', 'Santa María del Mercadillo', 'Burgos', '2022-05-21 10:54:38', 1, 1.0, 24.8, 24.8)
# (227, 'Dieter', 'Meyer', 'Calle K, nº 77', '43024', 'Bellvei', 'Tarragona', '2022-04-30 08:09:40', 1, 0.25, 20.5, 5.125)
# (228, 'Zia', 'Mosley', 'Calle X, nº 366', '06122', 'Santos de Maimona, Los', 'Badajoz', '2022-02-20 06:58:58', 1, 1.25, 19.9, 24.875)
# (229, 'Minerva', 'Cote', 'Calle B, nº 199', '05062', 'Collado de Contreras', 'Ávila', '2022-11-12 09:03:19', 1, 5.0, 18.7, 93.5)
# (230, 'Yuri', 'Hodges', 'Calle W, nº 169', '20013', 'Aretxabaleta', 'Gipuzkoa', '2022-04-06 20:11:22', 1, 0.5, 26.1, 13.05)
# (231, 'Gareth', 'Graves', 'Calle H, nº 17', '26082', 'Laguna de Cameros', 'La Rioja', '2022-05-08 06:22:13', 1, 2.0, 20.6, 41.2)
# (232, 'Regan', 'Rosario', 'Calle S, nº 75', '49190', 'San Martín de Valderaduey', 'Zamora', '2022-04-06 15:43:30', 1, 4.0, 23.1, 92.4)
# (233, 'Maris', 'Frye', 'Calle C, nº 72', '46009', 'Albalat dels Sorells', 'Valencia', '2022-05-25 02:36:42', 1, 0.5, 26.6, 13.3)
# (234, 'Rogan', 'Carter', 'Calle L, nº 239', '19078', 'Castilforte', 'Guadalajara', '2022-08-17 09:14:01', 1, 1.25, 34.5, 43.125)
# (235, 'Maris', 'Leach', 'Calle F, nº 338', '31161', 'Mañeru', 'Navarra', '2022-07-09 01:44:04', 1, 0.75, 27.1, 20.325000000000003)
# (236, 'Teegan', 'Shannon', 'Calle U, nº 354', '09274', 'Pradoluengo', 'Burgos', '2022-08-05 20:04:57', 1, 2.0, 26.8, 53.6)
# (237, 'Michael', 'Cooper', 'Calle R, nº 34', '09201', 'Mamolar', 'Burgos', '2022-08-15 11:48:43', 1, 1.5, 18.9, 28.349999999999998)
# (238, 'Yeo', 'Guerra', 'Calle W, nº 145', '34024', 'Baquerín de Campos', 'Palencia', '2022-01-23 07:19:33', 1, 0.75, 17.5, 13.125)
# (239, 'Price', 'Ashley', 'Calle K, nº 258', '02008', 'Alcaraz', 'Albacete', '2022-05-15 04:23:19', 1, 1.25, 25.5, 31.875)
# (240, 'Warren', 'Cantu', 'Calle M, nº 49', '42174', 'Sotillo del Rincón', 'Soria', '2022-11-03 02:14:37', 1, 0.75, 27.6, 20.700000000000003)
# (241, 'Urielle', 'Holland', 'Calle M, nº 51', '46034', 'Almoines', 'Valencia', '2022-04-17 21:19:10', 1, 3.0, 25.8, 77.4)
# (242, 'David', 'Clemons', 'Calle Q, nº 179', '09136', 'Fuentecén', 'Burgos', '2022-05-18 07:06:44', 1, 1.25, 34.0, 42.5)
# (243, 'Ivory', 'Poole', 'Calle O, nº 375', '26042', 'Casalarreina', 'La Rioja', '2022-08-01 17:04:15', 1, 5.0, 27.4, 137.0)
# (244, 'Robert', 'Bishop', 'Calle W, nº 278', '10003', 'Acebo', 'Cáceres', '2022-01-14 22:26:18', 1, 0.25, 31.0, 7.75)
# (245, 'Isabelle', 'Conrad', 'Calle P, nº 225', '01002', 'Amurrio', 'Álava', '2022-03-21 00:03:02', 1, 0.25, 33.3, 8.325)
# (246, 'Maxine', 'Armstrong', 'Calle D, nº 150', '31096', 'Espronceda', 'Navarra', '2022-04-01 06:19:23', 1, 5.0, 15.8, 79.0)
# (247, 'Wynter', 'Smith', 'Calle I, nº 335', '16113', 'Iniesta', 'Cuenca', '2022-06-14 16:43:57', 1, 3.0, 28.1, 84.30000000000001)
# (248, 'Vera', 'Strong', 'Calle S, nº 56', '37044', 'Barruecopardo', 'Salamanca', '2022-08-25 07:49:00', 1, 1.25, 23.6, 29.5)
# (249, 'Colette', 'Copeland', 'Calle C, nº 308', '44266', 'Visiedo', 'Teruel', '2022-06-14 12:42:28', 1, 1.25, 32.5, 40.625)
# (250, 'Colin', 'Rush', 'Calle E, nº 335', '40221', 'Valleruela de Sepúlveda', 'Segovia', '2022-01-31 10:24:51', 1, 0.75, 25.5, 19.125)
# (251, 'Samson', 'Saunders', 'Calle G, nº 55', '45022', 'Buenaventura', 'Toledo', '2022-10-18 01:53:29', 1, 2.0, 33.7, 67.4)
# (252, 'Yasir', 'Glover', 'Calle T, nº 31', '10192', 'Torremocha', 'Cáceres', '2022-10-31 15:16:48', 2, 0.25, 20.4, 5.1)
# (253, 'Cameran', 'Hyde', 'Calle M, nº 222', '39034', 'Lamasón', 'Cantabria', '2022-08-12 08:07:41', 2, 5.0, 19.4, 97.0)
# (254, 'Kristen', 'Webb', 'Calle H, nº 160', '40184', 'San Pedro de Gaíllos', 'Segovia', '2022-02-21 11:12:29', 2, 1.0, 32.4, 32.4)
# (255, 'Whitney', 'Macias', 'Calle H, nº 130', '08095', 'Granera', 'Barcelona', '2022-08-19 11:13:38', 2, 4.0, 17.0, 68.0)
# (256, 'Clarke', 'Mckinney', 'Calle T, nº 236', '09414', 'Valle de Valdelaguna', 'Burgos', '2022-03-19 22:20:12', 2, 3.0, 30.2, 90.6)
# (257, 'India', 'Hancock', 'Calle J, nº 195', '18077', 'Fornes', 'Granada', '2022-08-10 17:40:41', 2, 0.25, 31.8, 7.95)
# (258, 'Quintessa', 'Walter', 'Calle Q, nº 359', '19191', 'Monasterio', 'Guadalajara', '2022-04-12 20:22:59', 2, 1.25, 25.1, 31.375)
# (259, 'Karen', 'Hopper', 'Calle C, nº 376', '11019', 'Grazalema', 'Cádiz', '2022-07-29 10:00:20', 2, 1.5, 30.4, 45.599999999999994)
# (260, 'Kirby', 'Manning', 'Calle F, nº 26', '50039', 'Azuara', 'Zaragoza', '2022-04-15 08:52:57', 2, 1.0, 25.8, 25.8)
# (261, 'Freya', 'Mccarty', 'Calle E, nº 248', '37341', 'Valverde de Valdelacasa', 'Salamanca', '2022-05-10 10:00:33', 2, 0.25, 16.9, 4.225)
# (262, 'Damian', 'Kerr', 'Calle R, nº 151', '26170', 'Villar de Arnedo, El', 'La Rioja', '2022-04-22 17:49:41', 2, 2.0, 25.3, 50.6)
# (263, 'Anastasia', 'Schultz', 'Calle T, nº 345', '08285', 'Torelló', 'Barcelona', '2022-06-05 12:45:09', 2, 0.25, 20.7, 5.175)
# (264, 'Alexa', 'Guzman', 'Calle V, nº 149', '21039', 'Hinojales', 'Huelva', '2022-07-28 20:51:01', 2, 5.0, 24.5, 122.5)
# (265, 'Chaim', 'Byrd', 'Calle K, nº 272', '22046', 'Ballobar', 'Huesca', '2022-10-16 00:10:13', 2, 1.25, 26.5, 33.125)
# (266, 'Hall', 'Barron', 'Calle I, nº 322', '25254', 'Vilanova de la Barca', 'Lleida', '2022-12-25 06:43:31', 2, 2.0, 22.1, 44.2)
# (267, 'Alan', 'Watson', 'Calle C, nº 223', '49257', 'Villanueva de Azoague', 'Zamora', '2022-02-03 18:54:25', 2, 0.25, 17.2, 4.3)
# (268, 'Chancellor', 'Burris', 'Calle O, nº 8', '00000', 'Colmenarejo', 'Not_Found', '2022-05-28 21:56:52', 2, 0.25, 25.0, 6.25)
# (269, 'Kellie', 'Pennington', 'Calle W, nº 224', '34092', 'Lantadilla', 'Palencia', '2022-12-17 06:51:17', 2, 5.0, 24.5, 122.5)
# (270, 'Xaviera', 'Maddox', 'Calle S, nº 335', '40208', 'Turégano', 'Segovia', '2022-10-29 15:57:44', 2, 0.75, 33.3, 24.974999999999998)
# (271, 'Shay', 'Cabrera', 'Calle L, nº 189', '08278', 'Taradell', 'Barcelona', '2022-12-01 11:52:46', 2, 5.0, 33.3, 166.5)
# (272, 'Zahir', 'Foreman', 'Calle E, nº 102', '50114', 'Fuendetodos', 'Zaragoza', '2022-10-31 05:28:09', 2, 5.0, 18.6, 93.0)
# (273, 'Allistair', 'Mcknight', 'Calle S, nº 34', '10131', 'Navalmoral de la Mata', 'Cáceres', '2022-12-26 20:38:33', 2, 5.0, 31.3, 156.5)
# (274, 'Amal', 'Flores', 'Calle P, nº 14', '22115', 'Grado, El', 'Huesca', '2022-11-17 23:58:20', 2, 0.5, 23.7, 11.85)
# (275, 'Zephania', 'Mcneil', 'Calle U, nº 37', '47208', 'Villagómez la Nueva', 'Valladolid', '2022-11-16 06:06:14', 2, 1.5, 18.9, 28.349999999999998)
# (276, 'Diana', 'Carr', 'Calle W, nº 31', '38032', 'Rosario, El', 'Santa Cruz de Tenerife', '2022-08-03 04:43:01', 2, 1.5, 19.0, 28.5)
# (277, 'Constance', 'Hodge', 'Calle N, nº 110', '05264', 'Viñegra de Moraña', 'Ávila', '2022-02-06 10:22:11', 2, 1.0, 27.7, 27.7)
# (278, 'Tarik', 'Hawkins', 'Calle N, nº 105', '49138', 'Olmillos de Castro', 'Zamora', '2022-12-14 03:08:17', 2, 5.0, 26.6, 133.0)
# (279, 'Cairo', 'Sheppard', 'Calle C, nº 151', '25904', 'Castell de Mur', 'Lleida', '2022-03-30 02:43:17', 2, 1.5, 28.3, 42.45)
# (280, 'Juliet', 'Olsen', 'Calle Y, nº 199', '47181', 'Valdenebro de los Valles', 'Valladolid', '2022-02-25 20:57:15', 2, 1.25, 32.1, 40.125)
# (281, 'Noel', 'Boyer', 'Calle W, nº 325', '45151', 'San Martín de Montalbán', 'Toledo', '2022-08-09 18:24:03', 2, 0.25, 27.9, 6.975)
# (282, 'Connor', 'Knight', 'Calle F, nº 108', '08158', 'Papiol, El', 'Barcelona', '2022-12-30 08:06:12', 2, 5.0, 17.5, 87.5)
# (283, 'Xanthus', 'Mullins', 'Calle E, nº 88', '27018', 'Fonsagrada, A', 'Lugo', '2022-10-27 04:39:37', 2, 1.25, 17.2, 21.5)
# (284, 'Gary', 'Phillips', 'Calle Y, nº 211', '34184', 'Torremormojón', 'Palencia', '2022-03-26 23:31:00', 2, 2.0, 34.0, 68.0)
# (285, 'Quinlan', 'Buchanan', 'Calle K, nº 75', '18175', 'Santa Fe', 'Granada', '2022-09-08 22:47:07', 2, 0.25, 30.1, 7.525)
# (286, 'John', 'Booth', 'Calle Y, nº 344', '24073', 'Fresno de la Vega', 'León', '2022-09-06 03:57:08', 2, 2.0, 27.5, 55.0)
# (287, 'Shoshana', 'Willis', 'Calle K, nº 340', '14064', 'Valsequillo', 'Córdoba', '2022-07-31 14:36:41', 2, 1.0, 21.7, 21.7)
# (288, 'Tiger', 'Duncan', 'Calle V, nº 209', '24207', 'Villademor de la Vega', 'León', '2022-05-05 14:00:11', 2, 4.0, 28.6, 114.4)
# (289, 'Roary', 'Warren', 'Calle P, nº 2', '04100', 'Vera', 'Almería', '2022-10-22 08:34:36', 2, 3.0, 34.2, 102.60000000000001)
# (290, 'Uriah', 'Hayden', 'Calle X, nº 330', '44027', 'Arens de Lledó', 'Teruel', '2022-02-21 05:22:11', 2, 1.0, 25.8, 25.8)
# (291, 'Patricia', 'Preston', 'Calle N, nº 205', '27028', 'Lugo', 'Lugo', '2022-04-20 21:23:38', 2, 3.0, 22.0, 66.0)
# (292, 'Dalton', 'Pace', 'Calle B, nº 247', '12127', 'Vallibona', 'Castellón', '2022-05-19 20:28:31', 2, 0.5, 27.8, 13.9)
# (293, 'Larissa', 'Cole', 'Calle T, nº 387', '46099', 'Cortes de Pallás', 'Valencia', '2022-08-24 07:45:41', 2, 1.5, 22.9, 34.349999999999994)
# (294, 'Carol', 'Ramirez', 'Calle A, nº 326', '42090', 'Fuentepinilla', 'Soria', '2022-03-30 08:46:22', 2, 2.0, 29.8, 59.6)
# (295, 'Ivana', 'Gates', 'Calle Y, nº 398', '24184', 'Valdesamario', 'León', '2022-02-12 17:33:11', 2, 1.5, 23.5, 35.25)
# (296, 'Kerry', 'Mclaughlin', 'Calle C, nº 174', '41011', 'Arahal', 'Sevilla', '2022-12-06 17:19:09', 2, 3.0, 30.3, 90.9)
# (297, 'Vincent', 'Barnett', 'Calle F, nº 319', '34082', 'Hérmedes de Cerrato', 'Palencia', '2022-08-14 18:56:18', 2, 1.25, 24.0, 30.0)
# (298, 'Unity', 'Clay', 'Calle Q, nº 325', '43055', 'Falset', 'Tarragona', '2022-05-11 00:09:55', 2, 1.0, 30.4, 30.4)
# (299, 'Cedric', 'Decker', 'Calle F, nº 33', '42011', 'Aldealpozo', 'Soria', '2022-04-02 10:22:05', 2, 2.0, 26.4, 52.8)
# (300, 'Uriah', 'Hale', 'Calle L, nº 206', '44062', 'Cañada Vellida', 'Teruel', '2022-08-25 10:35:35', 2, 3.0, 18.2, 54.599999999999994)
# (301, 'Lillith', 'Kirkland', 'Calle I, nº 266', '08103', 'Jorba', 'Barcelona', '2022-10-18 19:26:26', 2, 1.5, 26.6, 39.900000000000006)
# (302, 'Cheryl', 'Reid', 'Calle E, nº 235', '26034', 'Briones', 'La Rioja', '2022-02-02 15:10:45', 2, 5.0, 22.8, 114.0)
# (303, 'Xantha', 'Prince', 'Calle P, nº 141', '16142', 'Olmedilla de Alarcón', 'Cuenca', '2022-08-10 18:05:24', 2, 4.0, 27.3, 109.2)
# (304, 'Michael', 'Gilmore', 'Calle R, nº 207', '50079', 'Cervera de la Cañada', 'Zaragoza', '2022-01-06 23:27:20', 2, 1.0, 33.5, 33.5)
# (305, 'Gary', 'Clements', 'Calle Q, nº 201', '01010', 'Ayala/Aiara', 'Álava', '2022-08-20 03:04:06', 2, 1.5, 16.9, 25.349999999999998)
# (306, 'Brenden', 'Sandoval', 'Calle U, nº 35', '05027', 'Berlanas, Las', 'Ávila', '2022-08-17 16:36:34', 2, 1.5, 30.8, 46.2)
# (307, 'Tatyana', 'Shepard', 'Calle Q, nº 287', '47149', 'San Pelayo', 'Valladolid', '2022-01-24 08:52:38', 2, 0.75, 20.4, 15.299999999999999)
# (308, 'Ignatius', 'Mathews', 'Calle W, nº 214', '20049', 'Lazkao', 'Gipuzkoa', '2022-09-02 07:46:54', 2, 4.0, 19.7, 78.8)
# (309, 'Kelly', 'Franklin', 'Calle K, nº 374', '10169', 'Santiago de Alcántara', 'Cáceres', '2022-12-26 05:27:41', 2, 2.0, 30.2, 60.4)
# (310, 'Vivien', 'Phelps', 'Calle Y, nº 9', '47165', 'Tordesillas', 'Valladolid', '2022-12-29 09:35:45', 2, 1.25, 20.0, 25.0)
# (311, 'Christopher', 'Ramirez', 'Calle V, nº 253', '45030', 'Calzada de Oropesa', 'Toledo', '2022-01-18 20:55:14', 2, 0.25, 23.9, 5.975)
# (312, 'Conan', 'Grant', 'Calle Y, nº 164', '26108', 'Ocón', 'La Rioja', '2022-07-22 17:41:27', 2, 2.0, 22.2, 44.4)
# (313, 'Azalia', 'Hawkins', 'Calle U, nº 39', '34208', 'Villaeles de Valdavia', 'Palencia', '2022-12-24 19:33:18', 2, 1.5, 15.8, 23.700000000000003)
# (314, 'Odette', 'Edwards', 'Calle X, nº 136', '23038', 'Guardia de Jaén, La', 'Jaén', '2022-12-09 13:23:09', 2, 0.75, 19.2, 14.399999999999999)
# (315, 'Daria', 'Molina', 'Calle J, nº 189', '19184', 'Millana', 'Guadalajara', '2022-08-11 22:40:30', 2, 1.0, 15.6, 15.6)
# (316, 'Clio', 'Anderson', 'Calle Z, nº 306', '37143', 'Galinduste', 'Salamanca', '2022-11-26 13:08:30', 2, 1.0, 24.1, 24.1)
# (317, 'Dane', 'Kaufman', 'Calle T, nº 369', '17002', 'Aiguaviva', 'Girona', '2022-06-19 19:39:14', 2, 0.25, 30.9, 7.725)
# (318, 'Bethany', 'Duncan', 'Calle Z, nº 164', '09046', 'Bascuñana', 'Burgos', '2022-09-22 09:00:54', 2, 1.0, 31.1, 31.1)
# (319, 'Olivia', 'David', 'Calle J, nº 205', '00000', 'Medinaceli', 'Not_Found', '2022-07-22 04:19:58', 2, 2.0, 22.8, 45.6)
# (320, 'Thaddeus', 'Holt', 'Calle U, nº 315', '09253', 'Pardilla', 'Burgos', '2022-03-30 10:50:55', 2, 0.75, 15.1, 11.325)
# (321, 'Colby', 'Campbell', 'Calle M, nº 257', '04901', 'Tres Villas, Las', 'Almería', '2022-02-06 21:49:32', 2, 1.25, 34.5, 43.125)
# (322, 'Mason', 'Rasmussen', 'Calle E, nº 11', '10050', 'Casar de Palomero', 'Cáceres', '2022-03-08 04:55:18', 2, 0.5, 28.7, 14.35)
# (323, 'Samuel', 'Cote', 'Calle N, nº 316', '43096', 'Morera de Montsant, La', 'Tarragona', '2022-01-12 20:11:17', 2, 2.0, 26.9, 53.8)
# (324, 'Lillith', 'Lopez', 'Calle L, nº 275', '45053', 'Consuegra', 'Toledo', '2022-02-14 10:39:16', 2, 3.0, 21.1, 63.300000000000004)
# (325, 'Neve', 'Mcgowan', 'Calle A, nº 322', '50245', 'Sigüés', 'Zaragoza', '2022-06-17 16:12:00', 2, 2.0, 23.2, 46.4)
# (326, 'Madison', 'Rocha', 'Calle T, nº 311', '09065', 'Campillo de Aranda', 'Burgos', '2022-11-03 12:53:52', 2, 0.75, 23.7, 17.775)
# (327, 'Harrison', 'Lowery', 'Calle P, nº 375', '18086', 'Gorafe', 'Granada', '2022-08-10 00:10:43', 2, 1.5, 33.8, 50.699999999999996)
# (328, 'Xantha', 'Forbes', 'Calle J, nº 137', '05115', 'Maello', 'Ávila', '2022-07-21 16:24:31', 2, 4.0, 28.2, 112.8)
# (329, 'Bree', 'Joyce', 'Calle D, nº 74', '45135', 'Puebla de Almoradiel, La', 'Toledo', '2022-05-18 21:21:54', 2, 1.5, 16.0, 24.0)
# (330, 'Bevis', 'Charles', 'Calle L, nº 71', '24055', 'Cimanes del Tejar', 'León', '2022-08-27 04:59:05', 2, 4.0, 27.6, 110.4)
# (331, 'Winifred', 'Ingram', 'Calle U, nº 58', '36031', 'Mondariz-Balneario', 'Pontevedra', '2022-06-11 15:24:06', 2, 1.0, 23.0, 23.0)
# (332, 'Howard', 'Bauer', 'Calle A, nº 228', '04046', 'Fondón', 'Almería', '2022-09-10 06:28:22', 2, 0.5, 27.4, 13.7)
# (333, 'Omar', 'Mcdonald', 'Calle C, nº 47', '46118', 'Enguera', 'Valencia', '2022-04-01 13:09:15', 2, 5.0, 32.1, 160.5)
# (334, 'Slade', 'Klein', 'Calle Z, nº 28', '13076', 'Santa Cruz de los Cáñamos', 'Ciudad Real', '2022-05-04 15:25:53', 2, 1.0, 18.1, 18.1)
# (335, 'Jackson', 'Rocha', 'Calle I, nº 385', '42027', 'Arévalo de la Sierra', 'Soria', '2022-01-08 18:59:12', 2, 0.5, 17.0, 8.5)
# (336, 'Plato', 'Robles', 'Calle G, nº 355', '34175', 'Serna, La', 'Palencia', '2022-10-21 05:05:39', 2, 1.5, 19.9, 29.849999999999998)
# (337, 'Derek', 'Parsons', 'Calle U, nº 240', '22195', 'Quicena', 'Huesca', '2022-04-07 09:10:38', 2, 0.5, 33.4, 16.7)
# (338, 'Honorato', 'Roy', 'Calle Q, nº 282', '41003', 'Albaida del Aljarafe', 'Sevilla', '2022-03-22 15:48:29', 2, 3.0, 28.6, 85.80000000000001)
# (339, 'Barbara', 'Charles', 'Calle W, nº 247', '28033', 'Campo Real', 'Madrid', '2022-08-21 01:14:07', 2, 0.25, 28.3, 7.075)
# (340, 'Octavia', 'Ingram', 'Calle T, nº 215', '16167', 'Pozorrubio de Santiago', 'Cuenca', '2022-08-08 04:16:31', 2, 1.0, 21.4, 21.4)
# (341, 'Colin', 'Mcdowell', 'Calle D, nº 116', '45127', 'Palomeque', 'Toledo', '2022-06-03 00:24:38', 2, 0.5, 28.5, 14.25)
# (342, 'Ursula', 'Lawrence', 'Calle R, nº 36', '47141', 'Salvador de Zapardiel', 'Valladolid', '2022-07-21 08:46:39', 2, 1.0, 19.3, 19.3)
# (343, 'Keane', 'Cortez', 'Calle X, nº 6', '06021', 'Bodonal de la Sierra', 'Badajoz', '2022-01-24 13:24:38', 2, 3.0, 19.0, 57.0)
# (344, 'Aladdin', 'Stanley', 'Calle M, nº 42', '18912', 'Cuevas del Campo', 'Granada', '2022-12-17 08:24:30', 2, 0.75, 34.4, 25.799999999999997)
# (345, 'Brendan', 'Leon', 'Calle R, nº 170', '37109', 'Colmenar de Montemayor', 'Salamanca', '2022-04-19 21:02:02', 2, 1.25, 34.7, 43.375)
# (346, 'Kylan', 'Kirby', 'Calle C, nº 266', '46263', 'Zarra', 'Valencia', '2022-09-15 14:35:54', 2, 0.75, 15.9, 11.925)
# (347, 'Sandra', 'Mckee', 'Calle J, nº 216', '39082', 'Selaya', 'Cantabria', '2022-08-04 19:17:00', 2, 5.0, 15.4, 77.0)
# (348, 'Tarik', 'Barlow', 'Calle I, nº 368', '44183', 'Pitarque', 'Teruel', '2022-01-27 21:31:16', 2, 0.75, 18.7, 14.024999999999999)
# (349, 'Edward', 'Huber', 'Calle A, nº 20', '25216', 'Talavera', 'Lleida', '2022-08-20 11:23:01', 2, 4.0, 33.2, 132.8)
# (350, 'Aline', 'Mccarty', 'Calle G, nº 251', '26144', 'Sorzano', 'La Rioja', '2022-11-07 08:01:40', 2, 0.25, 33.0, 8.25)
# (351, 'Martina', 'Petty', 'Calle G, nº 208', '50023', 'Almonacid de la Cuba', 'Zaragoza', '2022-03-08 09:22:28', 2, 1.25, 23.0, 28.75)
# (352, 'Quinlan', 'Lewis', 'Calle G, nº 151', '36043', 'Ponte Caldelas', 'Pontevedra', '2022-06-23 16:16:55', 2, 2.0, 29.7, 59.4)
# (353, 'Yen', 'Pitts', 'Calle N, nº 394', '50095', 'Ejea de los Caballeros', 'Zaragoza', '2022-06-04 13:07:07', 2, 0.75, 23.2, 17.4)
# (354, 'Kiona', 'Holmes', 'Calle P, nº 51', '08060', 'Castellfollit de Riubregós', 'Barcelona', '2022-07-12 16:52:05', 2, 2.0, 25.1, 50.2)
# (355, 'Destiny', 'Nguyen', 'Calle V, nº 289', '06068', 'Hinojosa del Valle', 'Badajoz', '2022-10-27 14:02:50', 2, 1.0, 19.9, 19.9)
# (356, 'Duncan', 'Decker', 'Calle N, nº 107', '03065', 'Elche/Elx', 'Alicante', '2022-01-17 02:33:48', 2, 1.25, 24.3, 30.375)
# (357, 'Lee', 'Oliver', 'Calle W, nº 199', '42071', 'Cubo de la Solana', 'Soria', '2022-03-26 00:31:50', 2, 3.0, 34.4, 103.19999999999999)
# (358, 'Aline', 'Hartman', 'Calle I, nº 292', '17055', 'Colomers', 'Girona', '2022-08-24 04:25:37', 2, 0.25, 27.4, 6.85)
# (359, 'Omar', 'Mcleod', 'Calle I, nº 29', '19039', 'Argecilla', 'Guadalajara', '2022-06-18 03:58:20', 2, 1.0, 30.9, 30.9)
# (360, 'Allistair', 'Carrillo', 'Calle E, nº 150', '28017', 'Batres', 'Madrid', '2022-10-28 19:30:57', 2, 1.25, 20.4, 25.5)
# (361, 'Driscoll', 'Hammond', 'Calle T, nº 100', '09192', 'Jurisdicción de San Zadornil', 'Burgos', '2022-01-09 14:22:48', 2, 1.5, 31.0, 46.5)
# (362, 'Otto', 'Rios', 'Calle R, nº 91', '49016', 'Aspariegos', 'Zamora', '2022-11-10 03:48:15', 2, 0.5, 25.0, 12.5)
# (363, 'Violet', 'Ortiz', 'Calle C, nº 314', '04012', 'Alicún', 'Almería', '2022-07-08 06:34:02', 2, 3.0, 15.6, 46.8)
# (364, 'Barbara', 'Farrell', 'Calle G, nº 143', '26066', 'Galilea', 'La Rioja', '2022-04-30 22:47:36', 2, 0.75, 32.8, 24.599999999999998)
# (365, 'Hoyt', 'Foreman', 'Calle E, nº 156', '25194', 'Sant Ramon', 'Lleida', '2022-08-29 00:30:32', 2, 0.25, 18.3, 4.575)
# (366, 'Otto', 'Mcdowell', 'Calle Z, nº 265', '49008', 'Almeida de Sayago', 'Zamora', '2022-08-30 13:54:28', 2, 1.25, 16.0, 20.0)
# (367, 'Preston', 'Burns', 'Calle P, nº 244', '33022', 'Degaña', 'Asturias', '2022-08-12 11:23:29', 2, 0.25, 16.6, 4.15)
# (368, 'Devin', 'Estes', 'Calle Z, nº 121', '02056', 'Ontur', 'Albacete', '2022-04-08 22:32:50', 2, 1.25, 32.5, 40.625)
# (369, 'Tucker', 'Miller', 'Calle J, nº 273', '14040', 'Montalbán de Córdoba', 'Córdoba', '2022-07-14 08:28:17', 2, 1.5, 30.6, 45.900000000000006)
# (370, 'Audrey', 'Golden', 'Calle H, nº 47', '22173', 'Peñas de Riglos, Las', 'Huesca', '2022-01-13 12:51:03', 2, 0.75, 32.3, 24.224999999999998)
# (371, 'Imogene', 'Blake', 'Calle S, nº 283', '28124', 'Robledillo de la Jara', 'Madrid', '2022-04-24 09:10:35', 2, 4.0, 33.0, 132.0)
# (372, 'Jonas', 'Webb', 'Calle M, nº 398', '05046', 'Canales', 'Ávila', '2022-07-10 23:45:35', 2, 3.0, 28.5, 85.5)
# (373, 'Tamara', 'Bradford', 'Calle H, nº 302', '18126', 'Malahá, La', 'Granada', '2022-11-04 14:49:23', 2, 5.0, 16.0, 80.0)
# (374, 'Lars', 'Glenn', 'Calle J, nº 230', '05097', 'Horcajada, La', 'Ávila', '2022-01-22 11:30:34', 2, 5.0, 25.6, 128.0)
# (375, 'Brendan', 'Gillespie', 'Calle J, nº 140', '37082', 'Cantalpino', 'Salamanca', '2022-07-22 20:54:23', 3, 3.0, 24.8, 74.4)
# (376, 'Joel', 'Gillespie', 'Calle I, nº 112', '01063', 'Zuia', 'Álava', '2022-10-13 04:32:53', 3, 4.0, 33.6, 134.4)
# (377, 'Xavier', 'Cardenas', 'Calle P, nº 324', '22232', 'Torralba de Aragón', 'Huesca', '2022-11-10 08:01:24', 3, 0.5, 23.2, 11.6)
# ...
# (869, 'Vivien', 'Wiggins', 'Calle T, nº 141', '25008', 'Albesa', 'Lleida', '2022-11-24 22:11:59', 6, 0.5, 26.4, 13.2)
# (870, 'Kelly', 'Wynn', 'Calle U, nº 163', '28073', 'Humanes de Madrid', 'Madrid', '2022-10-16 21:34:15', 6, 4.0, 22.6, 90.4)
# (871, 'Thor', 'Erickson', 'Calle D, nº 11', '40082', 'Fuente de Santa Cruz', 'Segovia', '2022-10-25 00:36:54', 6, 0.5, 32.7, 16.35)
# (872, 'Farrah', 'Poole', 'Calle C, nº 136', '37268', 'Rinconada de la Sierra, La', 'Salamanca', '2022-10-25 10:30:14', 6, 1.5, 17.8, 26.700000000000003)
# (873, 'Demetrius', 'Adkins', 'Calle T, nº 350', '46081', 'Canals', 'Valencia', '2022-10-24 18:26:59', 6, 5.0, 27.9, 139.5)
# (874, 'Amery', 'Abbott', 'Calle W, nº 55', '14033', 'Guadalcázar', 'Córdoba', '2022-03-31 11:25:35', 5, 3.0, 21.5, 64.5)
# (875, 'Mannix', 'Lambert', 'Calle T, nº 208', '07053', 'Santa Eugènia', 'Baleares', '2022-12-27 00:24:28', 5, 1.0, 32.1, 32.1)
# (876, 'Quon', 'Ross', 'Calle F, nº 287', '39050', 'Pesaguero', 'Cantabria', '2022-06-07 02:47:27', 5, 0.75, 20.0, 15.0)
# (877, 'Bruce', 'Burgess', 'Calle R, nº 334', '40040', 'Cantalejo', 'Segovia', '2022-11-02 22:50:56', 5, 4.0, 35.0, 140.0)
# (878, 'Kieran', 'Lott', 'Calle A, nº 288', '50188', 'Nombrevilla', 'Zaragoza', '2022-05-09 17:46:25', 5, 0.5, 29.1, 14.55)
# (879, 'Tashya', 'Mayer', 'Calle S, nº 353', '19259', 'Somolinos', 'Guadalajara', '2022-05-12 05:36:15', 5, 5.0, 22.0, 110.0)
# (880, 'Sara', 'Hopkins', 'Calle C, nº 119', '09074', 'Cardeñajimeno', 'Burgos', '2022-02-27 00:53:29', 5, 0.25, 16.4, 4.1)
# (881, 'Cameron', 'Lawson', 'Calle S, nº 195', '03041', 'Benissa', 'Alicante', '2022-06-16 09:46:25', 5, 2.0, 21.1, 42.2)
# (882, 'Xena', 'Ball', 'Calle P, nº 319', '50063', 'Buste, El', 'Zaragoza', '2022-06-21 22:31:35', 5, 4.0, 27.5, 110.0)
# (883, 'Zeph', 'Mccormick', 'Calle P, nº 152', '05158', 'Navalmoral', 'Ávila', '2022-12-11 18:35:40', 5, 1.5, 15.1, 22.65)
# (884, 'Ryder', 'Cruz', 'Calle O, nº 236', '08194', 'Sant Adrià de Besòs', 'Barcelona', '2022-04-04 23:53:37', 5, 1.25, 34.9, 43.625)
# (885, 'Oliver', 'Clemons', 'Calle J, nº 94', '42019', 'Almarza', 'Soria', '2022-05-23 02:10:20', 5, 0.25, 28.1, 7.025)
# (886, 'Brady', 'Cline', 'Calle N, nº 51', '46151', "Llocnou d'En Fenollet", 'Valencia', '2022-07-10 19:04:56', 5, 1.0, 16.1, 16.1)
# (887, 'Jesse', 'Combs', 'Calle P, nº 314', '25120', 'Lleida', 'Lleida', '2022-11-17 02:55:27', 5, 4.0, 28.7, 114.8)
# (888, 'Mallory', 'Daniels', 'Calle S, nº 264', '34123', 'Paredes de Nava', 'Palencia', '2022-09-07 16:32:58', 5, 0.5, 23.6, 11.8)
# (889, 'Kirsten', 'Gardner', 'Calle R, nº 222', '43127', 'Riudecanyes', 'Tarragona', '2022-09-12 19:41:54', 5, 0.5, 15.4, 7.7)
# (890, 'Berk', 'Holden', 'Calle G, nº 298', '19243', 'Rueda de la Sierra', 'Guadalajara', '2022-12-11 20:52:02', 5, 0.5, 28.5, 14.25)
# (891, 'Yael', 'Watkins', 'Calle Q, nº 386', '50131', 'Jaulín', 'Zaragoza', '2022-11-26 14:50:10', 5, 1.0, 24.8, 24.8)
# (892, 'Merritt', 'Bean', 'Calle S, nº 230', '29070', 'Mijas', 'Málaga', '2022-08-24 22:16:19', 5, 4.0, 33.9, 135.6)
# (893, 'Aaron', 'Rodgers', 'Calle B, nº 396', '39097', 'Vega de Pas', 'Cantabria', '2022-01-29 12:01:05', 5, 1.5, 22.6, 33.900000000000006)
# (894, 'Imani', 'Tillman', 'Calle D, nº 224', '05238', 'Solosancho', 'Ávila', '2022-06-05 10:08:42', 5, 3.0, 15.9, 47.7)
# (895, 'Kelly', 'Hinton', 'Calle S, nº 176', '07007', 'Banyalbufar', 'Baleares', '2022-01-25 12:23:23', 5, 0.75, 29.4, 22.049999999999997)
# (896, 'Dana', 'Sykes', 'Calle E, nº 165', '17190', 'Serinyà', 'Girona', '2022-07-06 04:21:31', 5, 0.5, 34.4, 17.2)
# (897, 'Uta', 'Franco', 'Calle K, nº 187', '25047', "Bellcaire d'Urgell", 'Lleida', '2022-11-13 02:44:54', 5, 5.0, 34.5, 172.5)
# (898, 'Denise', 'Rodriguez', 'Calle H, nº 285', '19251', 'Saúca', 'Guadalajara', '2022-10-25 21:21:12', 5, 5.0, 15.7, 78.5)
# (899, 'Keefe', 'Doyle', 'Calle M, nº 271', '44201', 'Rubielos de Mora', 'Teruel', '2022-03-05 11:32:56', 5, 0.75, 22.6, 16.950000000000003)
# (900, 'Madison', 'Flynn', 'Calle O, nº 4', '06092', 'Nogales', 'Badajoz', '2022-01-17 04:01:37', 5, 0.75, 31.6, 23.700000000000003)
# (901, 'Kareem', 'Boone', 'Calle E, nº 30', '02024', 'Casas-Ibáñez', 'Albacete', '2022-07-02 15:30:29', 5, 0.75, 20.7, 15.524999999999999)
# (902, 'Inez', 'Fischer', 'Calle R, nº 184', '40155', 'Palazuelos de Eresma', 'Segovia', '2022-03-18 08:34:39', 5, 2.0, 34.9, 69.8)
# (903, 'Sydnee', 'Huffman', 'Calle K, nº 54', '47081', 'Marzales', 'Valladolid', '2022-11-11 07:09:40', 5, 1.25, 28.8, 36.0)
# (904, 'Kieran', 'Downs', 'Calle R, nº 110', '08189', 'Sant Pere Sallavinera', 'Barcelona', '2022-11-13 19:57:57', 5, 3.0, 31.5, 94.5)
# (905, 'Galvin', 'Simpson', 'Calle G, nº 140', '22094', 'Chalamera', 'Huesca', '2022-06-10 03:11:38', 5, 1.25, 20.8, 26.0)
# (906, 'Juliet', 'Morgan', 'Calle A, nº 399', '18096', 'Huélago', 'Granada', '2022-01-27 10:47:06', 5, 2.0, 16.1, 32.2)
# (907, 'Nathan', 'Baxter', 'Calle C, nº 122', '12008', 'Algimia de Almonacid', 'Castellón', '2022-03-24 11:08:10', 5, 2.0, 28.2, 56.4)
# (908, 'Giacomo', 'Whitley', 'Calle Y, nº 362', '44236', 'Tronchón', 'Teruel', '2022-08-05 05:33:56', 5, 4.0, 17.6, 70.4)
# (909, 'Kennan', 'Pittman', 'Calle B, nº 101', '31108', 'Fustiñana', 'Navarra', '2022-05-13 20:15:13', 5, 0.25, 33.4, 8.35)
# (910, 'August', 'Snow', 'Calle W, nº 319', '37359', 'Villar de la Yegua', 'Salamanca', '2022-12-09 01:58:00', 5, 0.25, 26.5, 6.625)
# (911, 'Ralph', 'Best', 'Calle N, nº 56', '40146', 'Navas de San Antonio', 'Segovia', '2022-08-05 23:28:39', 5, 5.0, 20.8, 104.0)
# (912, 'Eric', 'Middleton', 'Calle H, nº 348', '03071', 'Gata de Gorgos', 'Alicante', '2022-06-28 00:22:25', 5, 4.0, 30.1, 120.4)
# (913, 'Ferris', 'Phillips', 'Calle B, nº 373', '46904', 'Benicull de Xúquer', 'Valencia', '2022-11-06 23:54:27', 5, 2.0, 34.4, 68.8)
# (914, 'Georgia', "O'brien", 'Calle O, nº 191', '09243', 'Padilla de Arriba', 'Burgos', '2022-01-22 21:28:47', 5, 4.0, 21.9, 87.6)
# (915, 'Rajah', 'Delaney', 'Calle F, nº 178', '08043', 'Canyelles', 'Barcelona', '2022-05-26 17:06:13', 5, 4.0, 15.0, 60.0)
# (916, 'Dawn', 'Everett', 'Calle V, nº 120', '19218', 'Pinilla de Jadraque', 'Guadalajara', '2022-04-29 15:10:42', 5, 3.0, 23.3, 69.9)
# (917, 'Bertha', 'Valencia', 'Calle W, nº 50', '31154', 'Lezaun', 'Navarra', '2022-08-26 14:02:10', 5, 1.25, 24.9, 31.125)
# (918, 'Desirae', 'Douglas', 'Calle J, nº 62', '31124', 'Ibargoiti', 'Navarra', '2022-07-16 05:45:38', 5, 1.25, 21.5, 26.875)
# (919, 'September', 'Bryant', 'Calle W, nº 132', '43047', 'Constantí', 'Tarragona', '2022-08-16 20:28:21', 5, 0.5, 23.9, 11.95)
# (920, 'Hadley', 'Peterson', 'Calle R, nº 391', '38008', 'Breña Alta', 'Santa Cruz de Tenerife', '2022-05-18 15:07:14', 5, 3.0, 18.7, 56.099999999999994)
# (921, 'Riley', 'Mcintosh', 'Calle C, nº 63', '41056', 'Luisiana, La', 'Sevilla', '2022-12-09 23:34:04', 5, 0.75, 23.2, 17.4)
# (922, 'Omar', 'Boyd', 'Calle S, nº 357', '42184', 'Torlengua', 'Soria', '2022-12-08 15:39:51', 5, 1.5, 17.7, 26.549999999999997)
# (923, 'Theodore', 'Clayton', 'Calle C, nº 74', '09105', 'Ciruelos de Cervera', 'Burgos', '2022-10-21 05:21:05', 5, 1.5, 22.3, 33.45)
# (924, 'Richard', 'Butler', 'Calle U, nº 336', '45166', 'Tembleque', 'Toledo', '2022-09-18 20:14:42', 5, 1.5, 28.1, 42.150000000000006)
# (925, 'Sade', 'Ware', 'Calle J, nº 285', '22016', 'Alcampell', 'Huesca', '2022-05-10 09:08:14', 5, 3.0, 29.6, 88.80000000000001)
# (926, 'Ainsley', 'Spence', 'Calle W, nº 313', '09906', 'Merindad de Río Ubierna', 'Burgos', '2022-01-28 00:55:20', 5, 4.0, 26.4, 105.6)
# (927, 'Dean', 'Faulkner', 'Calle L, nº 245', '19017', 'Algora', 'Guadalajara', '2022-02-16 21:08:18', 5, 1.5, 16.6, 24.900000000000002)
# (928, 'Brynn', 'James', 'Calle F, nº 356', '49273', 'Viñas', 'Zamora', '2022-01-16 19:47:33', 5, 0.25, 15.7, 3.925)
# (929, 'Zahir', 'Dale', 'Calle O, nº 283', '46259', 'Villargordo del Cabriel', 'Valencia', '2022-11-09 07:11:09', 5, 0.25, 17.9, 4.475)
# (930, 'Garth', 'Monroe', 'Calle L, nº 121', '50007', 'Aladrén', 'Zaragoza', '2022-06-17 09:12:05', 5, 2.0, 32.6, 65.2)
# (931, 'Britanney', 'Decker', 'Calle R, nº 95', '03106', 'Planes', 'Alicante', '2022-05-19 15:26:43', 5, 0.5, 21.9, 10.95)
# (932, 'Travis', 'Bell', 'Calle T, nº 94', '38039', 'Santa Úrsula', 'Santa Cruz de Tenerife', '2022-05-29 02:16:50', 5, 1.25, 20.0, 25.0)
# (933, 'Hashim', 'Horne', 'Calle S, nº 180', '01034', 'Leza', 'Álava', '2022-03-17 09:04:32', 5, 1.5, 33.2, 49.800000000000004)
# (934, 'Mari', 'Griffin', 'Calle B, nº 61', '23097', 'Villanueva del Arzobispo', 'Jaén', '2022-05-31 08:39:46', 5, 1.5, 17.6, 26.400000000000002)
# (935, 'Benedict', 'Spence', 'Calle K, nº 232', '46133', 'Gestalgar', 'Valencia', '2022-07-21 08:45:53', 5, 1.0, 25.7, 25.7)
# (936, 'Caleb', 'Alford', 'Calle H, nº 16', '45119', 'Numancia de la Sagra', 'Toledo', '2022-07-22 18:51:56', 5, 0.75, 27.3, 20.475)
# (937, 'Germaine', 'Woods', 'Calle C, nº 397', '37218', 'Navamorales', 'Salamanca', '2022-05-22 20:34:02', 5, 0.75, 23.8, 17.85)
# (938, 'Raymond', 'Terry', 'Calle B, nº 72', '31011', 'Allín/Allin', 'Navarra', '2022-10-19 12:33:04', 5, 1.0, 19.4, 19.4)
# (939, 'Tucker', 'Lowery', 'Calle E, nº 301', '05901', 'San Juan de Gredos', 'Ávila', '2022-10-14 20:51:41', 5, 0.25, 20.4, 5.1)
# (940, 'Unity', 'Blair', 'Calle Q, nº 265', '08269', 'Seva', 'Barcelona', '2022-01-26 05:33:22', 5, 0.25, 30.4, 7.6)
# (941, 'Dacey', 'Holt', 'Calle E, nº 278', '08203', 'Sant Cebrià de Vallalta', 'Barcelona', '2022-12-22 18:59:54', 5, 2.0, 32.2, 64.4)
# (942, 'Christian', 'Mckenzie', 'Calle C, nº 300', '31216', 'Sangüesa/Zangoza', 'Navarra', '2022-02-14 09:45:05', 5, 5.0, 20.5, 102.5)
# (943, 'Emmanuel', 'Wise', 'Calle D, nº 356', '26101', 'Muro en Cameros', 'La Rioja', '2022-11-29 18:04:21', 5, 0.25, 26.0, 6.5)
# (944, 'Cameron', 'Wheeler', 'Calle R, nº 143', '39010', 'Bárcena de Pie de Concha', 'Cantabria', '2022-02-15 22:28:36', 5, 1.0, 18.5, 18.5)
# (945, 'Erin', 'Clarke', 'Calle Q, nº 183', '48066', 'Morga', 'Bizkaia', '2022-12-13 22:53:45', 5, 3.0, 15.1, 45.3)
# (946, 'Driscoll', 'Tanner', 'Calle W, nº 218', '45071', 'Guardia, La', 'Toledo', '2022-12-24 04:56:38', 5, 2.0, 20.4, 40.8)
# (947, 'Talon', 'Stanley', 'Calle Y, nº 27', '09287', 'Quintanaortuño', 'Burgos', '2022-06-10 18:29:54', 5, 0.75, 30.2, 22.65)
# (948, 'Nell', 'Yang', 'Calle S, nº 225', '20006', 'Alkiza', 'Gipuzkoa', '2022-02-08 02:25:30', 5, 5.0, 30.3, 151.5)
# (949, 'Quinn', 'Spencer', 'Calle M, nº 52', '17211', 'Verges', 'Girona', '2022-01-20 07:12:39', 5, 0.75, 31.9, 23.924999999999997)
# (950, 'Deirdre', 'Cabrera', 'Calle Q, nº 74', '44129', 'Jatiel', 'Teruel', '2022-06-17 16:20:41', 5, 0.75, 27.7, 20.775)
# (951, 'Jessamine', 'Calderon', 'Calle N, nº 304', '06100', 'Peñalsordo', 'Badajoz', '2022-03-15 15:19:26', 5, 3.0, 26.9, 80.69999999999999)
# (952, 'Griffith', 'Adkins', 'Calle J, nº 77', '32053', 'Oímbra', 'Ourense', '2022-04-08 13:38:49', 5, 0.5, 26.1, 13.05)
# (953, 'Zeph', 'Farmer', 'Calle W, nº 19', '40191', 'Santo Tomé del Puerto', 'Segovia', '2022-05-22 13:18:34', 5, 0.5, 34.3, 17.15)
# (954, 'Salvador', 'Frazier', 'Calle U, nº 123', '05038', 'Bonilla de la Sierra', 'Ávila', '2022-12-08 03:52:38', 5, 5.0, 33.3, 166.5)
# (955, 'Harlan', 'Hansen', 'Calle K, nº 234', '06131', 'Torre de Miguel Sesmero', 'Badajoz', '2022-04-15 05:55:21', 5, 1.0, 34.7, 34.7)
# (956, 'Audra', 'Watts', 'Calle U, nº 189', '22106', 'Fago', 'Huesca', '2022-04-26 13:26:59', 5, 0.25, 22.6, 5.65)
# (957, 'Wilma', 'Hunt', 'Calle Z, nº 392', '49122', 'Monfarracinos', 'Zamora', '2022-01-22 16:50:01', 5, 3.0, 34.1, 102.30000000000001)
# (958, 'Paul', 'Landry', 'Calle M, nº 344', '38025', 'Matanza de Acentejo, La', 'Santa Cruz de Tenerife', '2022-03-27 15:54:30', 5, 3.0, 27.4, 82.19999999999999)
# (959, 'William', 'Cooke', 'Calle I, nº 376', '46160', 'Manuel', 'Valencia', '2022-05-22 12:03:22', 5, 3.0, 34.1, 102.30000000000001)
# (960, 'Charles', 'Perkins', 'Calle F, nº 61', '02063', 'Pozohondo', 'Albacete', '2022-07-04 21:18:45', 5, 0.75, 25.2, 18.9)
# (961, 'Mari', 'Spencer', 'Calle X, nº 268', '45087', 'Madridejos', 'Toledo', '2022-07-15 05:53:00', 5, 1.25, 32.2, 40.25)
# (962, 'Scott', 'Farmer', 'Calle Y, nº 329', '22024', 'Alquézar', 'Huesca', '2022-06-16 10:00:31', 5, 3.0, 23.1, 69.30000000000001)
# (963, 'Bert', 'Burgess', 'Calle V, nº 274', '09396', 'Tubilla del Lago', 'Burgos', '2022-08-01 08:21:19', 5, 0.25, 16.8, 4.2)
# (964, 'Scarlet', 'Stokes', 'Calle D, nº 11', '23071', 'Puente de Génave', 'Jaén', '2022-12-29 05:33:24', 5, 1.0, 26.3, 26.3)
# (965, 'Cherokee', 'Erickson', 'Calle R, nº 384', '22083', 'Castejón de Monegros', 'Huesca', '2022-08-27 04:59:54', 5, 1.0, 26.1, 26.1)
# (966, 'Davis', 'Castaneda', 'Calle Q, nº 273', '37275', 'Saldeana', 'Salamanca', '2022-09-28 09:54:41', 5, 1.25, 30.6, 38.25)
# (967, 'Emily', 'Mccoy', 'Calle U, nº 320', '05229', 'Santo Domingo de las Posadas', 'Ávila', '2022-09-26 11:37:58', 5, 2.0, 21.6, 43.2)
# (968, 'Octavius', 'Manning', 'Calle C, nº 61', '09056', 'Briviesca', 'Burgos', '2022-04-12 16:08:16', 5, 5.0, 30.9, 154.5)
# (969, 'Arsenio', 'Bullock', 'Calle T, nº 28', '04034', 'Cóbdar', 'Almería', '2022-06-20 00:56:25', 5, 1.25, 30.6, 38.25)
# (970, 'Adrienne', 'Shelton', 'Calle M, nº 381', '49165', 'Prado', 'Zamora', '2022-04-03 16:13:40', 5, 4.0, 30.8, 123.2)
# (971, 'Hannah', 'Morrow', 'Calle L, nº 365', '39066', 'Ruente', 'Cantabria', '2022-09-08 00:41:09', 5, 1.0, 21.5, 21.5)
# (972, 'Abraham', 'Williams', 'Calle R, nº 114', '22126', 'Ibieca', 'Huesca', '2022-07-16 04:00:58', 5, 1.5, 23.9, 35.849999999999994)
# (973, 'Bruce', 'Kirby', 'Calle N, nº 147', '99999', 'Bimenes', 'Not_Found', '2022-01-20 15:57:57', 5, 0.5, 18.1, 9.05)
# (974, 'Flynn', 'Mueller', 'Calle W, nº 134', '25027', 'Anglesola', 'Lleida', '2022-06-10 05:17:42', 5, 1.5, 18.3, 27.450000000000003)
# (975, 'Duncan', 'Newman', 'Calle N, nº 378', '46127', "Font d'En Carròs, la", 'Valencia', '2022-09-26 05:01:59', 5, 4.0, 29.4, 117.6)
# (976, 'April', 'Tate', 'Calle C, nº 84', '46184', 'Ontinyent', 'Valencia', '2022-06-03 21:06:21', 5, 4.0, 29.4, 117.6)
# (977, 'Myra', 'Madden', 'Calle H, nº 361', '16151', 'Paredes', 'Cuenca', '2022-02-24 22:46:13', 5, 3.0, 17.3, 51.900000000000006)
# (978, 'Nathaniel', 'Cooley', 'Calle C, nº 230', '38016', 'Garafía', 'Santa Cruz de Tenerife', '2022-02-17 09:54:28', 5, 4.0, 33.8, 135.2)
# (979, 'Dorothy', 'Moreno', 'Calle U, nº 200', '19047', 'Baides', 'Guadalajara', '2022-09-24 08:47:55', 5, 5.0, 18.8, 94.0)
# (980, 'Hyacinth', 'Hines', 'Calle L, nº 19', '42035', 'Berlanga de Duero', 'Soria', '2022-03-02 21:26:18', 5, 0.75, 15.5, 11.625)
# (981, 'Xenos', 'Chapman', 'Calle T, nº 397', '05008', 'Aldeaseca', 'Ávila', '2022-03-23 23:58:16', 5, 1.0, 24.8, 24.8)
# (982, 'Kessie', 'Battle', 'Calle N, nº 121', '34062', 'Congosto de Valdavia', 'Palencia', '2022-08-12 10:32:49', 5, 0.75, 16.1, 12.075000000000001)
# (983, 'Charity', 'Delaney', 'Calle S, nº 31', '11041', 'Villamartín', 'Cádiz', '2022-12-28 03:15:41', 5, 5.0, 31.4, 157.0)
# (984, 'Elvis', 'Flores', 'Calle G, nº 282', '34112', 'Nogal de las Huertas', 'Palencia', '2022-11-28 05:54:31', 5, 5.0, 30.5, 152.5)
# (985, 'Josiah', 'Hicks', 'Calle N, nº 344', '12061', 'Forcall', 'Castellón', '2022-12-05 06:59:24', 5, 1.25, 29.0, 36.25)
# (986, 'Kaitlin', 'Cantrell', 'Calle B, nº 7', '16199', 'Solera de Gabaldón', 'Cuenca', '2022-10-24 06:00:33', 5, 0.25, 26.0, 6.5)
# (987, 'Anastasia', 'Atkins', 'Calle I, nº 220', '50055', 'Borja', 'Zaragoza', '2022-07-25 13:25:46', 5, 1.25, 28.4, 35.5)
# (988, 'Drake', 'Waller', 'Calle Q, nº 85', '34140', 'Puebla de Valdavia, La', 'Palencia', '2022-06-19 08:50:03', 5, 1.0, 20.2, 20.2)
# (989, 'Rana', 'Underwood', 'Calle B, nº 154', '04085', 'Somontín', 'Almería', '2022-02-08 04:39:34', 5, 2.0, 24.5, 49.0)
# (990, 'Baxter', 'Parker', 'Calle T, nº 32', '08219', 'Vilassar de Mar', 'Barcelona', '2022-10-18 19:25:27', 5, 0.5, 26.0, 13.0)
# (991, 'Stephen', 'Barlow', 'Calle Q, nº 259', '06042', 'Cheles', 'Badajoz', '2022-03-15 04:30:30', 5, 3.0, 32.8, 98.39999999999999)
# (992, 'Willa', 'Mueller', 'Calle G, nº 244', '14018', 'Carpio, El', 'Córdoba', '2022-04-22 00:52:59', 5, 1.25, 15.3, 19.125)
# (993, 'Wyoming', 'Campos', 'Calle G, nº 114', '22162', 'Novales', 'Huesca', '2022-12-27 15:39:02', 5, 3.0, 31.0, 93.0)

# %% [markdown]
# (II.3) Get the following data, each of them just with one sql query if possible:
# * For the first 10 sales of the year, get their price per kilo and how does that compare to the average price per kilo in that province.

# %%
# From now on, I'm going to use the updated csv (sales_up.csv) that was created in the first part of this test.
# This time, I'll make the queries from pandas with the <pd.read_sql_query()> method.

# Load the sales_up.csv file into pandas dataframe
df = pd.read_csv("./sales_up.csv", parse_dates=["timestamp"])

# %%
conn = sqlite3.connect('embat_data')

query = '''
        SELECT
            *
        FROM
            sales_update
        ;
        '''

pd.read_sql_query(query, conn)
# Out:
#      index     name    surname          address postal_code  \
# 0        0     Cleo   Melendez  Calle U, nº 377       44175
# 1        1    Haley      Rivas  Calle K, nº 369       19095
# 2        2   Andrew    Whitley  Calle M, nº 196       47073
# 3        3   Galvin    Houston  Calle G, nº 355       19166
# 4        4       Hu      Brock  Calle T, nº 300       39058
# ..     ...      ...        ...              ...         ...
# 989    989     Rana  Underwood  Calle B, nº 154       04085
# 990    990   Baxter     Parker   Calle T, nº 32       08219
# 991    991  Stephen     Barlow  Calle Q, nº 259       06042
# 992    992    Willa    Mueller  Calle G, nº 244       14018
# 993    993  Wyoming     Campos  Calle G, nº 114       22162
#
#                    city     province            timestamp  type  amount_kg  \
# 0                Orrios       Teruel  2022-05-10 20:23:47     8       1.25
# 1    Condemios de Abajo  Guadalajara  2022-02-25 12:22:12     8       0.75
# 2      Herrín de Campos   Valladolid  2022-10-16 04:38:07     8       0.75
# 3     Málaga del Fresno  Guadalajara  2022-08-31 17:58:53     8       5.00
# 4               Rasines    Cantabria  2022-05-16 07:25:14     8       3.00
# ..                  ...          ...                  ...   ...        ...
# 989            Somontín      Almería  2022-02-08 04:39:34     5       2.00
# 990     Vilassar de Mar    Barcelona  2022-10-18 19:25:27     5       0.50
# 991              Cheles      Badajoz  2022-03-15 04:30:30     5       3.00
# 992          Carpio, El      Córdoba  2022-04-22 00:52:59     5       1.25
# 993             Novales       Huesca  2022-12-27 15:39:02     5       3.00
#
#      price_kg  sales_amount
# 0        24.8        31.000
# 1        29.2        21.900
# 2        25.7        19.275
# 3        20.3       101.500
# 4        27.6        82.800
# ..        ...           ...
# 989      24.5        49.000
# 990      26.0        13.000
# 991      32.8        98.400
# 992      15.3        19.125
# 993      31.0        93.000
#
# [994 rows x 12 columns]

# %%
query = '''
        SELECT
            province,
            price_kg,
            round (AVG (price_kg) OVER(PARTITION BY province) , 3) AS avgpp,
            round (price_kg / AVG (price_kg) OVER(PARTITION BY province) , 3) AS "%"
        FROM
            sales_update
        ORDER BY
            timestamp
        ;
        '''

pd.read_sql_query(query, conn).head(10)
# Out:
#      province  price_kg   avgpp      %
# 0      Huelva      17.8  26.350  0.676
# 1    Zaragoza      21.5  24.518  0.877
# 2  Valladolid      32.3  24.193  1.335
# 3      Zamora      25.3  25.031  1.011
# 4     Badajoz      31.5  26.438  1.191
# 5      Coruña      22.8  23.008  0.991
# 6   Barcelona      24.8  25.074  0.989
# 7      Zamora      18.6  25.031  0.743
# 8    Zaragoza      33.5  24.518  1.366
# 9  Valladolid      15.2  24.193  0.628

# %% [markdown]
# * Show all sales shipped to Madrid province with their date and amount (kg) of coffee sold, and for each of them show also the total amount of coffee sold in Madrid that same month.

# %%
query = '''
        SELECT
            province,
            STRFTIME("%Y-%m-%d", timestamp) AS date,
            amount_kg,
            SUM(amount_kg) OVER(PARTITION BY STRFTIME("%m", timestamp)) AS total_month
        FROM
            sales_update
        WHERE province = "Madrid"
        ;
        '''
pd.read_sql_query(query, conn)
# Out:
#    province        date  amount_kg  total_month
# 0    Madrid  2022-01-22       0.75         0.75
# 1    Madrid  2022-02-04       5.00         6.25
# 2    Madrid  2022-02-22       1.25         6.25
# 3    Madrid  2022-03-26       5.00         5.00
# 4    Madrid  2022-04-15       0.75         4.75
# 5    Madrid  2022-04-24       4.00         4.75
# 6    Madrid  2022-05-04       3.00         4.25
# 7    Madrid  2022-05-20       1.25         4.25
# 8    Madrid  2022-06-18       3.00         3.00
# 9    Madrid  2022-07-08       1.00         3.50
# 10   Madrid  2022-07-08       1.50         3.50
# 11   Madrid  2022-07-16       1.00         3.50
# 12   Madrid  2022-08-09       1.50         3.75
# 13   Madrid  2022-08-24       2.00         3.75
# 14   Madrid  2022-08-21       0.25         3.75
# 15   Madrid  2022-10-28       1.25         9.25
# 16   Madrid  2022-10-15       4.00         9.25
# 17   Madrid  2022-10-16       4.00         9.25
# 18   Madrid  2022-11-13       1.00         1.00
# 19   Madrid  2022-12-08       0.50         2.75
# 20   Madrid  2022-12-15       1.50         2.75
# 21   Madrid  2022-12-09       0.75         2.75

# %% [markdown]
# * Similar to the previous, show all sales shipped to Madrid province with their date and amount (kg) of coffee sold. Order the sales chronologically by month (all sales in january, then all sales in february, etc.) but also from higher to lower amount sold within each month.

# %%
query = '''
        SELECT
            province,
            STRFTIME("%m", timestamp) AS month,
            amount_kg,
            SUM(amount_kg) OVER(PARTITION BY STRFTIME("%m", timestamp)) AS total_month
        FROM
            sales_update
        WHERE province = "Madrid"
        ORDER BY month, amount_kg DESC
        ;
        '''
pd.read_sql_query(query, conn)
# Out:
#    province month  amount_kg  total_month
# 0    Madrid    01       0.75         0.75
# 1    Madrid    02       5.00         6.25
# 2    Madrid    02       1.25         6.25
# 3    Madrid    03       5.00         5.00
# 4    Madrid    04       4.00         4.75
# 5    Madrid    04       0.75         4.75
# 6    Madrid    05       3.00         4.25
# 7    Madrid    05       1.25         4.25
# 8    Madrid    06       3.00         3.00
# 9    Madrid    07       1.50         3.50
# 10   Madrid    07       1.00         3.50
# 11   Madrid    07       1.00         3.50
# 12   Madrid    08       2.00         3.75
# 13   Madrid    08       1.50         3.75
# 14   Madrid    08       0.25         3.75
# 15   Madrid    10       4.00         9.25
# 16   Madrid    10       4.00         9.25
# 17   Madrid    10       1.25         9.25
# 18   Madrid    11       1.00         1.00
# 19   Madrid    12       1.50         2.75
# 20   Madrid    12       0.75         2.75
# 21   Madrid    12       0.50         2.75
